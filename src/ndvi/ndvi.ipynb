# %%
pip install rioxarray

# %%
pip install xarray

# %%
pip install earthengine-api rasterio

# %%
pip install geopandas

# %%
pip install gdal==$(gdal-config --version) geemap

# %%
import ee
import geopandas as gpd
import os
from datetime import datetime, timedelta
import xarray as xr
import rioxarray
import rasterio

from rasterio.enums import Resampling
import numpy as np
from collections import defaultdict

# %%
import ee

# Trigger the authentication flow.
ee.Authenticate()

# Initialize the library.
ee.Initialize(project='btech-project-443813') # Make sure this project ID is correct

# %%
pip install setuptools geemap --upgrade

# %%
import ee
import geemap
import os
from datetime import datetime, timedelta

# Initialize Earth Engine
ee.Initialize()

# Define the region of interest (ROI)
# Define the region of interest (ROI) for Delhi, India
roi = ee.Geometry.Polygon([
    [76.8, 28.9],  # Northwest point
    [77.6, 28.9],  # Northeast point
    [77.6, 28.4],  # Southeast point
    [76.8, 28.4]   # Southwest point
])

# Define the date range
start_date = datetime(2008, 10, 1)
end_date = datetime(2023, 3, 31)

# Define the output directory on your local machine
output_dir = r'/home/stormej/dev/btech-project/data/ndvi/ndvi_tif'
os.makedirs(output_dir, exist_ok=True)


# Function to get NDVI monthly data

def get_monthly_ndvi(year, month):
    start = datetime(year, month, 1)
    end = (start + timedelta(days=32)).replace(day=1)

    dataset = ee.ImageCollection('MODIS/006/MOD09GA') \
        .filterDate(start.strftime('%Y-%m-%d'), end.strftime('%Y-%m-%d'))
    
    def addNDVI(image):
        ndvi = image.normalizedDifference(['sur_refl_b02', 'sur_refl_b01']).rename('NDVI')
        return image.addBands(ndvi)
    
    monthly_ndvi = dataset.map(addNDVI).select('NDVI').mean().clip(roi)
    return monthly_ndvi

# Function to download NDVI for a monthly data

def download_monthly_ndvi(year, month):
    date_str = datetime(year, month, 1).strftime('%Y-%m')
    ndvi = get_monthly_ndvi(year, month)
    filename = os.path.join(output_dir, f'ndvi_{date_str}.tif')

    geemap.ee_export_image(
        ndvi, 
        filename=filename, 
        scale=500,
        region=roi.getInfo()['coordinates'],
        crs='EPSG:4326'
    )
    print(f"Downloaded monthly NDVI for {date_str}")

# Download NDVI data for each day in the date range
current_date = start_date
while current_date <= end_date:
    download_monthly_ndvi(current_date.year, current_date.month)
    current_date += timedelta(days=1)

print("All NDVI data downloaded.")
# Out:
# /home/stormej/dev/btech-project/env/lib/python3.12/site-packages/ee/deprecation.py:207: DeprecationWarning:
#
# Attention required for MODIS/006/MOD09GA! You are using a deprecated asset.
# To ensure continued functionality, please update it.
# Learn more: https://developers.google.com/earth-engine/datasets/catalog/MODIS_006_MOD09GA
#
#   warnings.warn(warning, category=DeprecationWarning)
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/2270cce1fb8291f82c85809d7e70116e-a37ee8154566082e81b35d69e10b7594:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/ndvi_tif/ndvi_2008-10.tif
# Downloaded monthly NDVI for 2008-10
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/2270cce1fb8291f82c85809d7e70116e-f00a975d70a8a59940ce1d13da2998c1:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/ndvi_tif/ndvi_2008-10.tif
# Downloaded monthly NDVI for 2008-10
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/2270cce1fb8291f82c85809d7e70116e-ca996aec3c2f91d34b71fb0f53a56533:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/ndvi_tif/ndvi_2008-10.tif
# Downloaded monthly NDVI for 2008-10
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/2270cce1fb8291f82c85809d7e70116e-dc104dd35ec9ea1730a93948bd355fb1:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/ndvi_tif/ndvi_2008-10.tif
# Downloaded monthly NDVI for 2008-10
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/2270cce1fb8291f82c85809d7e70116e-dd5bbde8ee970583aaf342e938d8cb65:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/ndvi_tif/ndvi_2008-10.tif
# Downloaded monthly NDVI for 2008-10
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/2270cce1fb8291f82c85809d7e70116e-c5f1f126fc2f9cb50c7f02d539656712:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/ndvi_tif/ndvi_2008-10.tif
# Downloaded monthly NDVI for 2008-10
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/2270cce1fb8291f82c85809d7e70116e-16ee1f54c976eebeed273fbbc82337a6:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/ndvi_tif/ndvi_2008-10.tif
# Downloaded monthly NDVI for 2008-10
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/2270cce1fb8291f82c85809d7e70116e-6d6b496660315e5c8a486bbe452071cb:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/ndvi_tif/ndvi_2008-10.tif
# Downloaded monthly NDVI for 2008-10
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/2270cce1fb8291f82c85809d7e70116e-6ec8dd36be01761c1f6d735a906cb76b:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/ndvi_tif/ndvi_2008-10.tif
# Downloaded monthly NDVI for 2008-10
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/2270cce1fb8291f82c85809d7e70116e-1ab857e04dff26cfda0f822b6d891327:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/ndvi_tif/ndvi_2008-10.tif
# Downloaded monthly NDVI for 2008-10
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/2270cce1fb8291f82c85809d7e70116e-f022389221ce7f40488898d06d2f123b:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/ndvi_tif/ndvi_2008-10.tif
# Downloaded monthly NDVI for 2008-10
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/2270cce1fb8291f82c85809d7e70116e
folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)


# Find a reference rainfall file
reference_rainfall_path = None
for filename in os.listdir(rainfall_folder):
    if filename.endswith('.tif'):
        reference_rainfall_path = os.path.join(rainfall_folder, filename)
        break

if reference_rainfall_path is None:
    raise FileNotFoundError("No TIF file found in the rainfall folder")

print(f"Using reference rainfall file: {reference_rainfall_path}")

# Open the reference rainfall file to get its properties
with rasterio.open(reference_rainfall_path) as rainfall_src:
    rainfall_shape = (rainfall_src.height, rainfall_src.width)
    rainfall_crs = rainfall_src.crs
    rainfall_transform = rainfall_src.transform

print(f"Reference rainfall data shape: {rainfall_shape}, CRS: {rainfall_crs}")

# Process all LST files in the folder
for filename in os.listdir(input_folder):
    if filename.endswith('.tif'):
        lst_path = os.path.join(input_folder, filename)
        print(f"\nProcessing: {filename}")
        
        with rasterio.open(lst_path) as lst_src:
            lst_data = lst_src.read(1)
            print(f"LST data shape: {lst_data.shape}, dtype: {lst_data.dtype}")
            
            # Resample LST data using average method
            resampled_lst = lst_src.read(
                out_shape=(1, rainfall_shape[0], rainfall_shape[1]),
                resampling=Resampling.average
            )
            print(f"Resampled LST shape: {resampled_lst.shape}, dtype: {resampled_lst.dtype}")
            
            # Extract date from LST filename (handling format: lst_south_2010-01-01.tif)
            # Split by underscore and get the last part before .tif
            date_part = filename.split('_')[-1].split('.')[0]
            
            # Create output filename
            output_filename = f'modis_ndvi_avg_resampled_{date_part}.tif'
            output_path = os.path.join(output_folder, output_filename)
            
            # Save the resampled LST
            with rasterio.open(
                output_path,
                'w',
                driver='GTiff',
                height=resampled_lst.shape[1],
                width=resampled_lst.shape[2],
                count=1,
                dtype=resampled_lst.dtype,
                crs=rainfall_crs,
                transform=rainfall_transform,
            ) as dst:
                dst.write(resampled_lst[0], 1)
        
        print(f"Resampled LST saved to: {output_path}")

print("\nAll LST files have been resampled.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Using reference rainfall file: /home/stormej/dev/btech-project/data/reference_tif/refrence_tif.tif
# Reference rainfall data shape: (129, 135), CRS: EPSG:4326
#
# Processing: ndvi_2000-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2000-02.tif
#
# Processing: ndvi_2000-03.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2000-03.tif
#
# Processing: ndvi_2000-04.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2000-04.tif
#
# Processing: ndvi_2000-05.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2000-05.tif
#
# Processing: ndvi_2000-06.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2000-06.tif
#
# Processing: ndvi_2000-07.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2000-07.tif
#
# Processing: ndvi_2000-08.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2000-08.tif
#
# Processing: ndvi_2000-09.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2000-09.tif
#
# Processing: ndvi_2000-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2000-10.tif
#
# Processing: ndvi_2000-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2000-11.tif
#
# Processing: ndvi_2000-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2000-12.tif
#
# Processing: ndvi_2001-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2001-01.tif
#
# Processing: ndvi_2001-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2001-02.tif
#
# Processing: ndvi_2001-03.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2001-03.tif
#
# Processing: ndvi_2001-04.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2001-04.tif
#
# Processing: ndvi_2001-05.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2001-05.tif
#
# Processing: ndvi_2001-06.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2001-06.tif
#
# Processing: ndvi_2001-07.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2001-07.tif
#
# Processing: ndvi_2001-08.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2001-08.tif
#
# Processing: ndvi_2001-09.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2001-09.tif
#
# Processing: ndvi_2001-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2001-10.tif
#
# Processing: ndvi_2001-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2001-11.tif
#
# Processing: ndvi_2001-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2001-12.tif
#
# Processing: ndvi_2002-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2002-01.tif
#
# Processing: ndvi_2002-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2002-02.tif
#
# Processing: ndvi_2002-03.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2002-03.tif
#
# Processing: ndvi_2002-04.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2002-04.tif
#
# Processing: ndvi_2002-05.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2002-05.tif
#
# Processing: ndvi_2002-06.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2002-06.tif
#
# Processing: ndvi_2002-07.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2002-07.tif
#
# Processing: ndvi_2002-08.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2002-08.tif
#
# Processing: ndvi_2002-09.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2002-09.tif
#
# Processing: ndvi_2002-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2002-10.tif
#
# Processing: ndvi_2002-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2002-11.tif
#
# Processing: ndvi_2002-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2002-12.tif
#
# Processing: ndvi_2003-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2003-01.tif
#
# Processing: ndvi_2003-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2003-02.tif
#
# Processing: ndvi_2003-03.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2003-03.tif
#
# Processing: ndvi_2003-04.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2003-04.tif
#
# Processing: ndvi_2003-05.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2003-05.tif
#
# Processing: ndvi_2003-06.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2003-06.tif
#
# Processing: ndvi_2003-07.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2003-07.tif
#
# Processing: ndvi_2003-08.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2003-08.tif
#
# Processing: ndvi_2003-09.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2003-09.tif
#
# Processing: ndvi_2003-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2003-10.tif
#
# Processing: ndvi_2003-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2003-11.tif
#
# Processing: ndvi_2003-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2003-12.tif
#
# Processing: ndvi_2004-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2004-01.tif
#
# Processing: ndvi_2004-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2004-02.tif
#
# Processing: ndvi_2004-03.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2004-03.tif
#
# Processing: ndvi_2004-04.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2004-04.tif
#
# Processing: ndvi_2004-05.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2004-05.tif
#
# Processing: ndvi_2004-06.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2004-06.tif
#
# Processing: ndvi_2004-07.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2004-07.tif
#
# Processing: ndvi_2004-08.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2004-08.tif
#
# Processing: ndvi_2004-09.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2004-09.tif
#
# Processing: ndvi_2004-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2004-10.tif
#
# Processing: ndvi_2004-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2004-11.tif
#
# Processing: ndvi_2004-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2004-12.tif
#
# Processing: ndvi_2005-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2005-01.tif
#
# Processing: ndvi_2005-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2005-02.tif
#
# Processing: ndvi_2005-03.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2005-03.tif
#
# Processing: ndvi_2005-04.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2005-04.tif
#
# Processing: ndvi_2005-05.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2005-05.tif
#
# Processing: ndvi_2005-06.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2005-06.tif
#
# Processing: ndvi_2005-07.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2005-07.tif
#
# Processing: ndvi_2005-08.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2005-08.tif
#
# Processing: ndvi_2005-09.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2005-09.tif
#
# Processing: ndvi_2005-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2005-10.tif
#
# Processing: ndvi_2005-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2005-11.tif
#
# Processing: ndvi_2005-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2005-12.tif
#
# Processing: ndvi_2006-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2006-01.tif
#
# Processing: ndvi_2006-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2006-02.tif
#
# Processing: ndvi_2006-03.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2006-03.tif
#
# Processing: ndvi_2006-04.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2006-04.tif
#
# Processing: ndvi_2006-05.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2006-05.tif
#
# Processing: ndvi_2006-06.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2006-06.tif
#
# Processing: ndvi_2006-07.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2006-07.tif
#
# Processing: ndvi_2006-08.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2006-08.tif
#
# Processing: ndvi_2006-09.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2006-09.tif
#
# Processing: ndvi_2006-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2006-10.tif
#
# Processing: ndvi_2006-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2006-11.tif
#
# Processing: ndvi_2006-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2006-12.tif
#
# Processing: ndvi_2007-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2007-01.tif
#
# Processing: ndvi_2007-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2007-02.tif
#
# Processing: ndvi_2007-03.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2007-03.tif
#
# Processing: ndvi_2007-04.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2007-04.tif
#
# Processing: ndvi_2007-05.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2007-05.tif
#
# Processing: ndvi_2007-06.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2007-06.tif
#
# Processing: ndvi_2007-07.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2007-07.tif
#
# Processing: ndvi_2007-08.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2007-08.tif
#
# Processing: ndvi_2007-09.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2007-09.tif
#
# Processing: ndvi_2007-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2007-10.tif
#
# Processing: ndvi_2007-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2007-11.tif
#
# Processing: ndvi_2007-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2007-12.tif
#
# Processing: ndvi_2008-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2008-01.tif
#
# Processing: ndvi_2008-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2008-02.tif
#
# Processing: ndvi_2008-03.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2008-03.tif
#
# Processing: ndvi_2008-04.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2008-04.tif
#
# Processing: ndvi_2008-05.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2008-05.tif
#
# Processing: ndvi_2008-06.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2008-06.tif
#
# Processing: ndvi_2008-07.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2008-07.tif
#
# Processing: ndvi_2008-08.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2008-08.tif
#
# Processing: ndvi_2008-09.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2008-09.tif
#
# Processing: ndvi_2008-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2008-10.tif
#
# Processing: ndvi_2008-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2008-11.tif
#
# Processing: ndvi_2008-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2008-12.tif
#
# Processing: ndvi_2009-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2009-01.tif
#
# Processing: ndvi_2009-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2009-02.tif
#
# Processing: ndvi_2009-03.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2009-03.tif
#
# Processing: ndvi_2009-04.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2009-04.tif
#
# Processing: ndvi_2009-05.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2009-05.tif
#
# Processing: ndvi_2009-06.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2009-06.tif
#
# Processing: ndvi_2009-07.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2009-07.tif
#
# Processing: ndvi_2009-08.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2009-08.tif
#
# Processing: ndvi_2009-09.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2009-09.tif
#
# Processing: ndvi_2009-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2009-10.tif
#
# Processing: ndvi_2009-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2009-11.tif
#
# Processing: ndvi_2009-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2009-12.tif
#
# Processing: ndvi_2010-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2010-01.tif
#
# Processing: ndvi_2010-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2010-02.tif
#
# Processing: ndvi_2010-03.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2010-03.tif
#
# Processing: ndvi_2010-04.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2010-04.tif
#
# Processing: ndvi_2010-05.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2010-05.tif
#
# Processing: ndvi_2010-06.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2010-06.tif
#
# Processing: ndvi_2010-07.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2010-07.tif
#
# Processing: ndvi_2010-08.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2010-08.tif
#
# Processing: ndvi_2010-09.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2010-09.tif
#
# Processing: ndvi_2010-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2010-10.tif
#
# Processing: ndvi_2010-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2010-11.tif
#
# Processing: ndvi_2010-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2010-12.tif
#
# Processing: ndvi_2011-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2011-01.tif
#
# Processing: ndvi_2011-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2011-02.tif
#
# Processing: ndvi_2011-03.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2011-03.tif
#
# Processing: ndvi_2011-04.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2011-04.tif
#
# Processing: ndvi_2011-05.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2011-05.tif
#
# Processing: ndvi_2011-06.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2011-06.tif
#
# Processing: ndvi_2011-07.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2011-07.tif
#
# Processing: ndvi_2011-08.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2011-08.tif
#
# Processing: ndvi_2011-09.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2011-09.tif
#
# Processing: ndvi_2011-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2011-10.tif
#
# Processing: ndvi_2011-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2011-11.tif
#
# Processing: ndvi_2011-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2011-12.tif
#
# Processing: ndvi_2012-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2012-01.tif
#
# Processing: ndvi_2012-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2012-02.tif
#
# Processing: ndvi_2012-03.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2012-03.tif
#
# Processing: ndvi_2012-04.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2012-04.tif
#
# Processing: ndvi_2012-05.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2012-05.tif
#
# Processing: ndvi_2012-06.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2012-06.tif
#
# Processing: ndvi_2012-07.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2012-07.tif
#
# Processing: ndvi_2012-08.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2012-08.tif
#
# Processing: ndvi_2012-09.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2012-09.tif
#
# Processing: ndvi_2012-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2012-10.tif
#
# Processing: ndvi_2012-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2012-11.tif
#
# Processing: ndvi_2012-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2012-12.tif
#
# Processing: ndvi_2013-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2013-01.tif
#
# Processing: ndvi_2013-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2013-02.tif
#
# Processing: ndvi_2013-03.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2013-03.tif
#
# Processing: ndvi_2013-04.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2013-04.tif
#
# Processing: ndvi_2013-05.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2013-05.tif
#
# Processing: ndvi_2013-06.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2013-06.tif
#
# Processing: ndvi_2013-07.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2013-07.tif
#
# Processing: ndvi_2013-08.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2013-08.tif
#
# Processing: ndvi_2013-09.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2013-09.tif
#
# Processing: ndvi_2013-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2013-10.tif
#
# Processing: ndvi_2013-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2013-11.tif
#
# Processing: ndvi_2013-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2013-12.tif
#
# Processing: ndvi_2014-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2014-01.tif
#
# Processing: ndvi_2014-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2014-02.tif
#
# Processing: ndvi_2014-03.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2014-03.tif
#
# Processing: ndvi_2014-04.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2014-04.tif
#
# Processing: ndvi_2014-05.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2014-05.tif
#
# Processing: ndvi_2014-06.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2014-06.tif
#
# Processing: ndvi_2014-07.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2014-07.tif
#
# Processing: ndvi_2014-08.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2014-08.tif
#
# Processing: ndvi_2014-09.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2014-09.tif
#
# Processing: ndvi_2014-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2014-10.tif
#
# Processing: ndvi_2014-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2014-11.tif
#
# Processing: ndvi_2014-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2014-12.tif
#
# Processing: ndvi_2015-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2015-01.tif
#
# Processing: ndvi_2015-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2015-02.tif
#
# Processing: ndvi_2015-03.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2015-03.tif
#
# Processing: ndvi_2015-04.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2015-04.tif
#
# Processing: ndvi_2015-05.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2015-05.tif
#
# Processing: ndvi_2015-06.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2015-06.tif
#
# Processing: ndvi_2015-07.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2015-07.tif
#
# Processing: ndvi_2015-08.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2015-08.tif
#
# Processing: ndvi_2015-09.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2015-09.tif
#
# Processing: ndvi_2015-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2015-10.tif
#
# Processing: ndvi_2015-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2015-11.tif
#
# Processing: ndvi_2015-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2015-12.tif
#
# Processing: ndvi_2016-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2016-01.tif
#
# Processing: ndvi_2016-02.tif
# ...
#
# Processing: ndvi_2017-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2017-10.tif
#
# Processing: ndvi_2017-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2017-11.tif
#
# Processing: ndvi_2017-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2017-12.tif
#
# Processing: ndvi_2018-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2018-01.tif
#
# Processing: ndvi_2018-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2018-02.tif
#
# Processing: ndvi_2018-03.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2018-03.tif
#
# Processing: ndvi_2018-04.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2018-04.tif
#
# Processing: ndvi_2018-05.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2018-05.tif
#
# Processing: ndvi_2018-06.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2018-06.tif
#
# Processing: ndvi_2018-07.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2018-07.tif
#
# Processing: ndvi_2018-08.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2018-08.tif
#
# Processing: ndvi_2018-09.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2018-09.tif
#
# Processing: ndvi_2018-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2018-10.tif
#
# Processing: ndvi_2018-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2018-11.tif
#
# Processing: ndvi_2018-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2018-12.tif
#
# Processing: ndvi_2019-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2019-01.tif
#
# Processing: ndvi_2019-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2019-02.tif
#
# Processing: ndvi_2019-03.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2019-03.tif
#
# Processing: ndvi_2019-04.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2019-04.tif
#
# Processing: ndvi_2019-05.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2019-05.tif
#
# Processing: ndvi_2019-06.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2019-06.tif
#
# Processing: ndvi_2019-07.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2019-07.tif
#
# Processing: ndvi_2019-08.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2019-08.tif
#
# Processing: ndvi_2019-09.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2019-09.tif
#
# Processing: ndvi_2019-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2019-10.tif
#
# Processing: ndvi_2019-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2019-11.tif
#
# Processing: ndvi_2019-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2019-12.tif
#
# Processing: ndvi_2020-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2020-01.tif
#
# Processing: ndvi_2020-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2020-02.tif
#
# Processing: ndvi_2020-03.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2020-03.tif
#
# Processing: ndvi_2020-04.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2020-04.tif
#
# Processing: ndvi_2020-05.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2020-05.tif
#
# Processing: ndvi_2020-06.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2020-06.tif
#
# Processing: ndvi_2020-07.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2020-07.tif
#
# Processing: ndvi_2020-08.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2020-08.tif
#
# Processing: ndvi_2020-09.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2020-09.tif
#
# Processing: ndvi_2020-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2020-10.tif
#
# Processing: ndvi_2020-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2020-11.tif
#
# Processing: ndvi_2020-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2020-12.tif
#
# Processing: ndvi_2021-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2021-01.tif
#
# Processing: ndvi_2021-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2021-02.tif
#
# Processing: ndvi_2021-03.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2021-03.tif
#
# Processing: ndvi_2021-04.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2021-04.tif
#
# Processing: ndvi_2021-05.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2021-05.tif
#
# Processing: ndvi_2021-06.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2021-06.tif
#
# Processing: ndvi_2021-07.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2021-07.tif
#
# Processing: ndvi_2021-08.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2021-08.tif
#
# Processing: ndvi_2021-09.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2021-09.tif
#
# Processing: ndvi_2021-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2021-10.tif
#
# Processing: ndvi_2021-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2021-11.tif
#
# Processing: ndvi_2021-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2021-12.tif
#
# Processing: ndvi_2022-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2022-01.tif
#
# Processing: ndvi_2022-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2022-02.tif
#
# Processing: ndvi_2022-03.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2022-03.tif
#
# Processing: ndvi_2022-04.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2022-04.tif
#
# Processing: ndvi_2022-05.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2022-05.tif
#
# Processing: ndvi_2022-06.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2022-06.tif
#
# Processing: ndvi_2022-07.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2022-07.tif
#
# Processing: ndvi_2022-08.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2022-08.tif
#
# Processing: ndvi_2022-09.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2022-09.tif
#
# Processing: ndvi_2022-10.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2022-10.tif
#
# Processing: ndvi_2022-11.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2022-11.tif
#
# Processing: ndvi_2022-12.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2022-12.tif
#
# Processing: ndvi_2023-01.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2023-01.tif
#
# Processing: ndvi_2023-02.tif
# LST data shape: (113, 179), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/ndvi_resampled_monthly/modis_ndvi_avg_resampled_2023-02.tif
#
# All LST files have been resampled.
