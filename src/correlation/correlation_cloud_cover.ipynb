# %%
pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /home/stormej/dev/varsha/env/lib/python3.12/site-packages (1.4.2)
# Requirement already satisfied: affine in /home/stormej/dev/varsha/env/lib/python3.12/site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /home/stormej/dev/varsha/env/lib/python3.12/site-packages (from rasterio) (24.2.0)
# Requirement already satisfied: certifi in /home/stormej/dev/varsha/env/lib/python3.12/site-packages (from rasterio) (2024.8.30)
# Requirement already satisfied: click>=4.0 in /home/stormej/dev/varsha/env/lib/python3.12/site-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /home/stormej/dev/varsha/env/lib/python3.12/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /home/stormej/dev/varsha/env/lib/python3.12/site-packages (from rasterio) (2.1.3)
# Requirement already satisfied: click-plugins in /home/stormej/dev/varsha/env/lib/python3.12/site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in /home/stormej/dev/varsha/env/lib/python3.12/site-packages (from rasterio) (3.2.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /home/stormej/dev/varsha/env/lib/python3.12/site-packages (2.1.3)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in /home/stormej/dev/varsha/env/lib/python3.12/site-packages (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /home/stormej/dev/varsha/env/lib/python3.12/site-packages (from scipy) (2.1.3)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Corrected Code
# Correlation between IMD Rainfall and LST data

import os
import numpy as np
import rasterio
from glob import glob
from datetime import datetime
from dateutil.relativedelta import relativedelta

# Define folders
imd_folder = r'/home/stormej/dev/varsha/data/rain/rain_resampled_monthly'
cloud_cover_folder = r'/home/stormej/dev/varsha/data/cloud_cover/cloud_cover_resampled'
output_folder = r'/home/stormej/dev/varsha/data/correlation/cloud_cover_imd'

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Initialize arrays to store sums
sum_imd, sum_lst, sum_imd_squared, sum_lst_squared, sum_product, count = (None,) * 6

# Get list of all files
imd_files = glob(os.path.join(imd_folder, 'imd_rain_sum_resampled_*.tif'))
lst_files = glob(os.path.join(cloud_cover_folder, 'modis_cloud_cover_avg_resampled_*.tif'))

# Sort the files to ensure they're processed in order
imd_files.sort()
lst_files.sort()

# Print file counts for debugging
print(f"Total IMD files found: {len(imd_files)}")
print(f"Total LST files found: {len(lst_files)}")

# Function to extract date from filename
def extract_date(filename):
    """
    Extracts the date from the file name.
    Assumes IMD files are in the format 'imd_rain_sum_resampled_YYYY-MM.tif' and
    LST files are in the format 'modis_lst_avg_resampled_YYYY-MM.tif'.
    """
    return datetime.strptime(filename.split('_')[-2] + '-' + filename.split('_')[-1].split('.')[0], '%Y-%m')

# Process each pair of files
successfully_processed = 0
total_files = len(lst_files)

for index, lst_file in enumerate(lst_files, 1):
    lst_date = extract_date(os.path.basename(lst_file))

    # Find matching IMD file
    # Add 0 month lag to the LST date
    lst_date_lead = lst_date
    imd_date_str = lst_date_lead.strftime('%Y-%m')
    matching_imd_file = next((f for f in imd_files if imd_date_str in f), None)

    if matching_imd_file:
        # Read LST data
        with rasterio.open(lst_file) as src:
            lst_data = src.read(1)
            if sum_lst is None:
                # Initialize arrays based on the shape of LST data
                sum_imd = np.zeros_like(lst_data, dtype=np.float64)
                sum_lst = np.zeros_like(lst_data, dtype=np.float64)
                sum_imd_squared = np.zeros_like(lst_data, dtype=np.float64)
                sum_lst_squared = np.zeros_like(lst_data, dtype=np.float64)
                sum_product = np.zeros_like(lst_data, dtype=np.float64)
                count = np.zeros_like(lst_data, dtype=np.int32)
                meta = src.meta

        # Read IMD data
        with rasterio.open(matching_imd_file) as src:
            imd_data = src.read(1)

        # Create a mask for valid data
        mask = ~np.isnan(imd_data) & ~np.isnan(lst_data)
        mask = mask & (imd_data >= 0) & (lst_data >= 0)

        if np.any(mask):
            # Update sums
            sum_imd[mask] += imd_data[mask]
            sum_lst[mask] += lst_data[mask]
            sum_imd_squared[mask] += imd_data[mask] ** 2
            sum_lst_squared[mask] += lst_data[mask] ** 2
            sum_product[mask] += imd_data[mask] * lst_data[mask]
            count[mask] += 1
            successfully_processed += 1

        else:
            print(f"Warning: No valid pixels found for LST: {lst_date.strftime('%Y-%m')} and IMD: {imd_date_str}")

    else:
        print(f"No matching IMD file for LST date: {lst_date.strftime('%Y-%m')}")

    # Print progress every 10 files
    if index % 10 == 0:
        print(f"Processed {index}/{total_files} files. Successfully matched: {successfully_processed}")

# Compute correlation and save output
if count is not None and np.sum(count) > 0:
    # Pearson correlation calculation
    n = count
    numerator = n * sum_product - sum_imd * sum_lst
    denominator = np.sqrt((n * sum_imd_squared - sum_imd ** 2) * (n * sum_lst_squared - sum_lst ** 2))
    valid_mask = (denominator > 0) & (n > 0)
    pearson_corr = np.full_like(sum_imd, np.nan)
    pearson_corr[valid_mask] = numerator[valid_mask] / denominator[valid_mask]

    # Save as GeoTIFF
    output_file = os.path.join(output_folder, 'pearson_correlation_monthly_imd_cloud_cover.tif')
    meta.update(dtype='float32', nodata=np.nan)

    with rasterio.open(output_file, 'w', **meta) as dst:
        dst.write(pearson_corr.astype('float32'), 1)

    print(f"Correlation saved to {output_file}")
else:
    print("No valid data to calculate correlation.")
# Out:
# Total IMD files found: 276
# Total LST files found: 253
# Warning: No valid pixels found for LST: 2000-01 and IMD: 2000-01
# Processed 10/253 files. Successfully matched: 9
# Warning: No valid pixels found for LST: 2001-02 and IMD: 2001-02
# Processed 20/253 files. Successfully matched: 18
# Processed 30/253 files. Successfully matched: 28
# Warning: No valid pixels found for LST: 2003-01 and IMD: 2003-01
# Warning: No valid pixels found for LST: 2003-05 and IMD: 2003-05
# Processed 40/253 files. Successfully matched: 36
# Processed 50/253 files. Successfully matched: 46
# Processed 60/253 files. Successfully matched: 56
# Warning: No valid pixels found for LST: 2006-01 and IMD: 2006-01
# Warning: No valid pixels found for LST: 2006-02 and IMD: 2006-02
# Processed 70/253 files. Successfully matched: 64
# Warning: No valid pixels found for LST: 2007-01 and IMD: 2007-01
# Warning: No valid pixels found for LST: 2007-03 and IMD: 2007-03
# Processed 80/253 files. Successfully matched: 72
# Processed 90/253 files. Successfully matched: 82
# Warning: No valid pixels found for LST: 2009-01 and IMD: 2009-01
# Processed 100/253 files. Successfully matched: 91
# Warning: No valid pixels found for LST: 2009-02 and IMD: 2009-02
# Processed 110/253 files. Successfully matched: 100
# Processed 120/253 files. Successfully matched: 110
# Warning: No valid pixels found for LST: 2011-01 and IMD: 2011-01
# Processed 130/253 files. Successfully matched: 119
# Warning: No valid pixels found for LST: 2012-02 and IMD: 2012-02
# Warning: No valid pixels found for LST: 2012-03 and IMD: 2012-03
# Processed 140/253 files. Successfully matched: 127
# Warning: No valid pixels found for LST: 2013-03 and IMD: 2013-03
# Processed 150/253 files. Successfully matched: 136
# Warning: No valid pixels found for LST: 2014-01 and IMD: 2014-01
# Processed 160/253 files. Successfully matched: 145
# Warning: No valid pixels found for LST: 2015-02 and IMD: 2015-02
# Processed 170/253 files. Successfully matched: 154
# Warning: No valid pixels found for LST: 2016-02 and IMD: 2016-02
# Processed 180/253 files. Successfully matched: 163
# Warning: No valid pixels found for LST: 2017-01 and IMD: 2017-01
# Warning: No valid pixels found for LST: 2017-02 and IMD: 2017-02
# Processed 190/253 files. Successfully matched: 171
# Warning: No valid pixels found for LST: 2018-01 and IMD: 2018-01
# Warning: No valid pixels found for LST: 2018-02 and IMD: 2018-02
# Processed 200/253 files. Successfully matched: 179
# Processed 210/253 files. Successfully matched: 189
# Processed 220/253 files. Successfully matched: 199
# Processed 230/253 files. Successfully matched: 209
# Processed 240/253 files. Successfully matched: 219
# Warning: No valid pixels found for LST: 2022-02 and IMD: 2022-02
# Processed 250/253 files. Successfully matched: 228
# Correlation saved to /home/stormej/dev/varsha/data/correlation/cloud_cover_imd/pearson_correlation_monthly_imd_cloud_cover.tif
# /tmp/ipykernel_676663/3028256220.py:104: RuntimeWarning: invalid value encountered in sqrt
#   denominator = np.sqrt((n * sum_imd_squared - sum_imd ** 2) * (n * sum_lst_squared - sum_lst ** 2))

# %%
from matplotlib.colors import ListedColormap, BoundaryNorm
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

def plot_correlation_map_delhi(file_path):
    # Load the GeoTIFF file
    with rasterio.open(file_path) as src:
        correlation_data = src.read(1)
        # Get the transformation parameters
        transform = src.transform
        height = src.height
        width = src.width
        
        # Calculate coordinates properly using the transform
        lon = np.linspace(transform[2], transform[2] + width * transform[0], width)
        lat = np.linspace(transform[5] + height * transform[4], transform[5], height)
        
        # Create meshgrid for proper plotting
        lon_mesh, lat_mesh = np.meshgrid(lon, lat)

    # Create color map
    colors = ['#053061', '#2166ac', '#4393c3', '#92c5de', '#d1e5f0', '#f7f7f7', 
              '#fddbc7', '#f4a582', '#d6604d', '#b2182b', '#62001f']
   
    cmap = ListedColormap(colors)
    norm = BoundaryNorm(np.linspace(-0.1, 0.1, len(colors) + 1), cmap.N)

    # Create figure with adjusted extent
    fig, ax = plt.subplots(figsize=(12, 10), 
                           subplot_kw={'projection': ccrs.PlateCarree()})
    
    # Set extent to cover the Delhi region (adjusted bounds)
    ax.set_extent([76.7, 77.5, 28.4, 28.9], crs=ccrs.PlateCarree())

    # Plot the correlation data using pcolormesh with explicit coordinates
    correlation_plot = ax.pcolormesh(
        lon_mesh, lat_mesh, correlation_data,
        transform=ccrs.PlateCarree(),
        cmap=cmap,
        norm=norm,
        shading='auto'  # Add shading parameter
    )

    # Add features with zorder to control layering
    ax.add_feature(cfeature.BORDERS, linewidth=1.2, edgecolor='black', zorder=3)
    ax.add_feature(cfeature.COASTLINE, linewidth=1, edgecolor='black', zorder=3)
    ax.add_feature(cfeature.STATES, linewidth=0.5, edgecolor='black', zorder=2)

    # Add and format gridlines
    gl = ax.gridlines(draw_labels=True, linewidth=0.5, color='gray', 
                     linestyle='--', zorder=1)
    gl.top_labels = False
    gl.right_labels = False
    gl.xformatter = LONGITUDE_FORMATTER
    gl.yformatter = LATITUDE_FORMATTER
    gl.xlabel_style = {'size': 10, 'color': 'black'}
    gl.ylabel_style = {'size': 10, 'color': 'black'}

    # Add colorbar
    cbar = plt.colorbar(correlation_plot, ax=ax, orientation='horizontal', 
                       pad=0.05, fraction=0.04)
    cbar.set_label('Pearson Correlation Coefficient (r)', fontsize=12)
    cbar.ax.tick_params(labelsize=10)

    # Set title
    plt.title("Pearson's Correlation between monthly IMD and Cloud Cover Rainfall (2000-2022) - Delhi Region", 
             fontsize=15, pad=20)

    return fig, ax

# Define the file path for the correlation data
file_path = os.path.join(output_folder, 'pearson_correlation_monthly_imd_cloud_cover.tif')

# Usage
fig, ax = plot_correlation_map_delhi(file_path)
plt.show()

# %% [markdown]
# # Correlation between IMD Rainfall and Cloud Rainfall in Delhi Region between years 2000 and 2022
#
# **No correlation**
#
# As we get a zero correlation, it means that this is not a good auxillary variable for our purpose.
