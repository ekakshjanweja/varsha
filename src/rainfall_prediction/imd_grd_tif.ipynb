# %%
pip install rioxarray

# %%
pip install numpy gdal==$(gdal-config --version)

# %%
pip install scipy

# %%
pip install matplotlib

# %%
pip install geopandas

# %%
from osgeo import gdal
import xarray as xr
import rioxarray as rxr
import os
from glob import glob
from datetime import datetime, timedelta
import numpy as np
import calendar
import numpy as n
import rasterio

# %%
import os
from datetime import datetime, timedelta
from glob import glob
import numpy as np
from osgeo import gdal, osr
import warnings
warnings.filterwarnings('ignore')

def get_delhi_bounds():
    """Define the bounding box for Delhi region"""
    return {
        'min_lon': 76.5,  # Western boundary of Delhi
        'max_lon': 77.5,  # Eastern boundary of Delhi
        'min_lat': 28.3,  # Southern boundary of Delhi
        'max_lat': 28.9   # Northern boundary of Delhi
    }

def convert_grd_to_daily_tiff(grd_file, output_dir):
    """Convert GRD file to daily GeoTIFF files for Delhi region"""
    try:
        # Extract year from filename (assuming format YYYY.grd)
        year = os.path.basename(grd_file).split('.')[0]
        print(f"Processing year: {year}")
        
        # Open the .grd file and read its content
        with open(grd_file, 'rb') as f:
            data = f.read()
        print(f"Read {len(data)} bytes from {grd_file}")
        
        # Determine the number of days in the year
        is_leap_year = (int(year) % 4 == 0 and int(year) % 100 != 0) or (int(year) % 400 == 0)
        days_in_year = 366 if is_leap_year else 365
        print(f"Year {year} has {days_in_year} days")
        
        # Convert binary data to numpy array
        all_data = np.frombuffer(data, dtype=np.float32)
        
        # For 0.25° x 0.25° grid covering India
        grid_size = 129 * 135  # Total number of grid cells
        
        # Get Delhi bounds
        bounds = get_delhi_bounds()
        
        # Calculate array indices for clipping
        min_x = int((bounds['min_lon'] - 65.0) / 0.25)
        max_x = int((bounds['max_lon'] - 65.0) / 0.25)
        min_y = int((40.0 - bounds['max_lat']) / 0.25)  # Flip Y coordinates
        max_y = int((40.0 - bounds['min_lat']) / 0.25)
        
        # Calculate new dimensions
        new_width = max_x - min_x + 1
        new_height = max_y - min_y + 1
        
        for day in range(days_in_year):
            date = datetime(int(year), 1, 1) + timedelta(days=day)
            output_filename = f"imd_25_delhi_{date.strftime('%Y-%m-%d')}.tif"
            output_file = os.path.join(output_dir, output_filename)
            
            # Extract data for the current day and the Delhi region
            day_data = all_data[day * grid_size : (day + 1) * grid_size].reshape(129, 135)[min_y:max_y+1, min_x:max_x+1]
            
            # Create a new GeoTIFF file
            driver = gdal.GetDriverByName('GTiff')
            dataset = driver.Create(output_file, new_width, new_height, 1, gdal.GDT_Float32)
            
            # Set geotransform for the clipped region
            geotransform = (
                bounds['min_lon'],  # Left edge
                0.25,               # Pixel width
                0,                  # Rotation (0 if image is "north up")
                bounds['max_lat'],  # Top edge
                0,                  # Rotation (0 if image is "north up")
                -0.25              # Pixel height (negative as it goes from top to bottom)
            )
            dataset.SetGeoTransform(geotransform)
            
            # Set projection (WGS84)
            srs = osr.SpatialReference()
            srs.ImportFromEPSG(4326)
            dataset.SetProjection(srs.ExportToWkt())
            
            # Write the clipped data
            dataset.GetRasterBand(1).WriteArray(day_data)
            
            # Set NoData value
            dataset.GetRasterBand(1).SetNoDataValue(-999)
            
            # Close the dataset
            dataset = None
            
            if os.path.exists(output_file):
                print(f"Successfully saved {output_file}")
            else:
                print(f"Failed to create {output_file}")
            
    except Exception as e:
        print(f"Failed to process {grd_file}: {str(e)}")
        raise

def main():
    # Define the directory containing the rainfall .grd files
    rainfall_dir = r'/home/stormej/dev/varsha/data/rain/rain_grd'
    
    # Define the output directory for the daily .tif files
    output_dir = r'/home/stormej/dev/varsha/data/rain/rain_tif'
    os.makedirs(output_dir, exist_ok=True)
    
    # List all .grd files in the rainfall directory
    grd_files = glob(os.path.join(rainfall_dir, '*.grd'))
    
    if not grd_files:
        print(f"No .grd files found in {rainfall_dir}")
    else:
        for grd_file in grd_files:
            print(f"Processing {grd_file}...")
            convert_grd_to_daily_tiff(grd_file, output_dir)
    
    print("Script execution completed.")
main()
# Out:
# Processing /home/stormej/dev/varsha/data/rain/rain_grd/2000.grd...
# Processing year: 2000
# Read 25495560 bytes from /home/stormej/dev/varsha/data/rain/rain_grd/2000.grd
# Year 2000 has 366 days
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-01.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-02.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-03.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-04.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-05.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-06.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-07.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-08.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-09.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-10.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-11.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-12.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-13.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-14.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-15.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-16.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-17.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-18.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-19.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-20.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-21.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-22.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-23.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-24.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-25.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-26.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-27.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-28.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-29.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-30.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-01-31.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-01.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-02.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-03.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-04.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-05.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-06.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-07.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-08.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-09.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-10.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-11.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-12.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-13.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-14.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-15.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-16.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-17.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-18.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-19.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-20.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-21.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-22.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-23.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-24.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-25.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-26.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-27.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-28.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-02-29.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-01.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-02.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-03.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-04.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-05.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-06.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-07.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-08.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-09.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-10.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-11.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-12.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-13.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-14.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-15.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-16.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-17.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-18.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-19.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-20.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-21.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-22.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-23.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-24.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-25.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-26.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-27.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-28.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-29.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-30.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-03-31.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-01.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-02.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-03.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-04.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-05.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-06.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-07.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-08.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-09.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-10.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-11.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-12.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-13.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-14.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-15.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-16.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-17.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-18.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-19.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-20.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-21.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-22.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-23.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-24.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-25.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-26.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-27.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-28.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-29.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-04-30.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-01.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-02.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-03.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-04.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-05.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-06.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-07.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-08.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-09.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-10.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-11.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-12.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-13.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-14.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-15.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-16.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-17.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-18.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-19.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-20.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-21.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-22.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-23.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-24.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-25.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-26.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-27.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-28.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-29.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-30.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-05-31.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-01.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-02.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-03.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-04.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-05.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-06.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-07.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-08.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-09.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-10.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-11.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-12.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-13.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-14.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-15.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-16.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-17.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-18.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-19.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-20.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-21.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-22.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-23.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-24.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-25.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-26.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-27.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-28.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-29.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-06-30.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-01.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-02.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-03.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-04.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-05.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-06.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-07.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-08.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-09.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-10.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-11.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-12.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-13.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-14.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-15.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-16.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-17.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-18.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-19.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-20.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-21.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-22.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-23.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-24.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-25.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-26.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-27.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-28.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-29.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-30.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-07-31.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-01.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-02.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-03.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-04.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-05.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-06.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-07.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-08.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-09.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-10.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-11.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-12.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-13.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-14.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-15.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-16.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-17.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-18.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-19.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-20.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-21.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-22.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-23.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-24.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-25.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-26.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-27.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-28.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-29.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-30.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-08-31.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-09-01.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-09-02.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-09-03.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-09-04.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-09-05.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-09-06.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-09-07.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-09-08.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-09-09.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-09-10.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-09-11.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-09-12.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-09-13.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-09-14.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-09-15.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-09-16.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-09-17.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-09-18.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-09-19.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000-09-20.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2000
tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-10-31.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-01.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-02.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-03.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-04.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-05.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-06.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-07.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-08.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-09.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-10.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-11.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-12.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-13.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-14.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-15.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-16.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-17.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-18.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-19.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-20.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-21.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-22.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-23.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-24.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-25.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-26.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-27.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-28.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-29.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-11-30.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-01.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-02.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-03.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-04.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-05.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-06.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-07.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-08.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-09.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-10.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-11.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-12.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-13.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-14.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-15.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-16.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-17.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-18.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-19.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-20.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-21.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-22.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-23.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-24.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-25.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-26.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-27.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-28.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-29.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-30.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif/imd_25_delhi_2023-12-31.tif
# Script execution completed.

# %%
import os
from datetime import datetime, timedelta
from glob import glob
import numpy as np
from osgeo import gdal, osr
import warnings
warnings.filterwarnings('ignore')

def get_delhi_bounds():
    """Define the bounding box for Delhi region"""
    return {
        'min_lon': 76.5,  # Western boundary of Delhi
        'max_lon': 77.5,  # Eastern boundary of Delhi
        'min_lat': 28.3,  # Southern boundary of Delhi
        'max_lat': 28.9   # Northern boundary of Delhi
    }

def convert_grd_to_monthly_tiff(grd_file, output_dir):
    """Convert GRD file to monthly GeoTIFF files for Delhi region"""
    try:
        # Extract year from filename (assuming format YYYY.grd)
        year = os.path.basename(grd_file).split('.')[0]
        print(f"Processing year: {year}")
        
        # Open the .grd file and read its content
        with open(grd_file, 'rb') as f:
            data = f.read()
        print(f"Read {len(data)} bytes from {grd_file}")
        
        # Determine the number of days in the year
        is_leap_year = (int(year) % 4 == 0 and int(year) % 100 != 0) or (int(year) % 400 == 0)
        days_in_year = 366 if is_leap_year else 365
        print(f"Year {year} has {days_in_year} days")
        
        # Convert binary data to numpy array
        all_data = np.frombuffer(data, dtype=np.float32)
        
        # For 0.25° x 0.25° grid covering India
        grid_size = 129 * 135  # Total number of grid cells
        
        # Get Delhi bounds
        bounds = get_delhi_bounds()
        
        # Calculate array indices for clipping
        min_x = int((bounds['min_lon'] - 65.0) / 0.25)
        max_x = int((bounds['max_lon'] - 65.0) / 0.25)
        min_y = int((40.0 - bounds['max_lat']) / 0.25)  # Flip Y coordinates
        max_y = int((40.0 - bounds['min_lat']) / 0.25)
        
        # Calculate new dimensions
        new_width = max_x - min_x + 1
        new_height = max_y - min_y + 1
        
        # Create a 3D numpy array to store monthly rainfall data
        monthly_rainfall = np.zeros((12, new_height, new_width), dtype=np.float32)
        
        for day in range(days_in_year):
            date = datetime(int(year), 1, 1) + timedelta(days=day)
            month = date.month - 1  # Adjust month index to 0-11 range
            
            # Extract data for the current day and the Delhi region
            day_data = all_data[day * grid_size : (day + 1) * grid_size].reshape(129, 135)[min_y:max_y+1, min_x:max_x+1]
            
            # Add the daily rainfall to the corresponding monthly array
            monthly_rainfall[month] += day_data
        
        for month in range(12):
            date = datetime(int(year), month + 1, 1)
            output_filename = f"imd_25_delhi_{date.strftime('%Y-%m')}.tif"
            output_file = os.path.join(output_dir, output_filename)
            
            # Create a new GeoTIFF file
            driver = gdal.GetDriverByName('GTiff')
            dataset = driver.Create(output_file, new_width, new_height, 1, gdal.GDT_Float32)
            
            # Set geotransform for the clipped region
            geotransform = (
                bounds['min_lon'],  # Left edge
                0.25,               # Pixel width
                0,                  # Rotation (0 if image is "north up")
                bounds['max_lat'],  # Top edge
                0,                  # Rotation (0 if image is "north up")
                -0.25              # Pixel height (negative as it goes from top to bottom)
            )
            dataset.SetGeoTransform(geotransform)
            
            # Set projection (WGS84)
            srs = osr.SpatialReference()
            srs.ImportFromEPSG(4326)
            dataset.SetProjection(srs.ExportToWkt())
            
            # Write the monthly rainfall data
            dataset.GetRasterBand(1).WriteArray(monthly_rainfall[month])
            
            # Set NoData value
            dataset.GetRasterBand(1).SetNoDataValue(-999)
            
            # Close the dataset
            dataset = None
            
            if os.path.exists(output_file):
                print(f"Successfully saved {output_file}")
            else:
                print(f"Failed to create {output_file}")
            
    except Exception as e:
        print(f"Failed to process {grd_file}: {str(e)}")
        raise

def main():
    # Define the directory containing the rainfall .grd files
    rainfall_dir = r'/home/stormej/dev/varsha/data/rain/rain_grd'
    
    # Define the output directory for the monthly .tif files
    output_dir = r'/home/stormej/dev/varsha/data/rain/rain_tif_monthly'
    os.makedirs(output_dir, exist_ok=True)
    
    # List all .grd files in the rainfall directory
    grd_files = glob(os.path.join(rainfall_dir, '*.grd'))
    
    if not grd_files:
        print(f"No .grd files found in {rainfall_dir}")
    else:
        for grd_file in grd_files:
            print(f"Processing {grd_file}...")
            convert_grd_to_monthly_tiff(grd_file, output_dir)
    
    print("Script execution completed.")


main()
# Out:
# Processing /home/stormej/dev/varsha/data/rain/rain_grd/2000.grd...
# Processing year: 2000
# Read 25495560 bytes from /home/stormej/dev/varsha/data/rain/rain_grd/2000.grd
# Year 2000 has 366 days
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2000-01.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2000-02.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2000-03.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2000-04.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2000-05.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2000-06.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2000-07.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2000-08.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2000-09.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2000-10.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2000-11.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2000-12.tif
# Processing /home/stormej/dev/varsha/data/rain/rain_grd/2001.grd...
# Processing year: 2001
# Read 25425900 bytes from /home/stormej/dev/varsha/data/rain/rain_grd/2001.grd
# Year 2001 has 365 days
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2001-01.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2001-02.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2001-03.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2001-04.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2001-05.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2001-06.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2001-07.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2001-08.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2001-09.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2001-10.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2001-11.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2001-12.tif
# Processing /home/stormej/dev/varsha/data/rain/rain_grd/2002.grd...
# Processing year: 2002
# Read 25425900 bytes from /home/stormej/dev/varsha/data/rain/rain_grd/2002.grd
# Year 2002 has 365 days
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2002-01.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2002-02.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2002-03.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2002-04.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2002-05.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2002-06.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2002-07.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2002-08.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2002-09.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2002-10.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2002-11.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2002-12.tif
# Processing /home/stormej/dev/varsha/data/rain/rain_grd/2003.grd...
# Processing year: 2003
# Read 25425900 bytes from /home/stormej/dev/varsha/data/rain/rain_grd/2003.grd
# Year 2003 has 365 days
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2003-01.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2003-02.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2003-03.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2003-04.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2003-05.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2003-06.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2003-07.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2003-08.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2003-09.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2003-10.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2003-11.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2003-12.tif
# Processing /home/stormej/dev/varsha/data/rain/rain_grd/2004.grd...
# Processing year: 2004
# Read 25495560 bytes from /home/stormej/dev/varsha/data/rain/rain_grd/2004.grd
# Year 2004 has 366 days
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2004-01.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2004-02.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2004-03.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2004-04.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2004-05.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2004-06.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2004-07.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2004-08.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2004-09.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2004-10.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2004-11.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_
tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2023-11.tif
# Successfully saved /home/stormej/dev/varsha/data/rain/rain_tif_monthly/imd_25_delhi_2023-12.tif
# Script execution completed.

# %%
#Resampling imd monthly data to imd data i.e 0.25 degree

import os
import rasterio
from rasterio.enums import Resampling
# # Paths
# rainfall_folder = r'/home/stormej/dev/btech-project/data/rain_tif'  # Folder containing all rainfall files
rainfall_folder = r'/home/stormej/dev/varsha/data/reference_tif'  # Folder containing reference files
input_folder = r'/home/stormej/dev/varsha/data/rain/rain_tif_monthly'  # Folder containing all LST files
output_folder = r'/home/stormej/dev/varsha/data/rain/rain_resampled_monthly'  # Folder to save resampled files

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)


# Find a reference rainfall file
reference_rainfall_path = None
for filename in os.listdir(rainfall_folder):
    if filename.endswith('.tif'):
        reference_rainfall_path = os.path.join(rainfall_folder, filename)
        break

if reference_rainfall_path is None:
    raise FileNotFoundError("No TIF file found in the rainfall folder")

print(f"Using reference rainfall file: {reference_rainfall_path}")

# Open the reference rainfall file to get its properties
with rasterio.open(reference_rainfall_path) as rainfall_src:
    rainfall_shape = (rainfall_src.height, rainfall_src.width)
    rainfall_crs = rainfall_src.crs
    rainfall_transform = rainfall_src.transform

print(f"Reference rainfall data shape: {rainfall_shape}, CRS: {rainfall_crs}")

# Process all LST files in the folder
for filename in os.listdir(input_folder):
    if filename.endswith('.tif'):
        lst_path = os.path.join(input_folder, filename)
        print(f"\nProcessing: {filename}")
        
        with rasterio.open(lst_path) as lst_src:
            lst_data = lst_src.read(1)
            print(f"LST data shape: {lst_data.shape}, dtype: {lst_data.dtype}")
            
            # Resample LST data using average method
            resampled_lst = lst_src.read(
                out_shape=(1, rainfall_shape[0], rainfall_shape[1]),
                resampling=Resampling.average
            )
            print(f"Resampled LST shape: {resampled_lst.shape}, dtype: {resampled_lst.dtype}")
            
            # Extract date from LST filename (handling format: lst_south_2010-01-01.tif)
            # Split by underscore and get the last part before .tif
            date_part = filename.split('_')[-1].split('.')[0]
            
            # Create output filename
            output_filename = f'imd_rain_sum_resampled_{date_part}.tif'
            output_path = os.path.join(output_folder, output_filename)
            
            # Save the resampled LST
            with rasterio.open(
                output_path,
                'w',
                driver='GTiff',
                height=resampled_lst.shape[1],
                width=resampled_lst.shape[2],
                count=1,
                dtype=resampled_lst.dtype,
                crs=rainfall_crs,
                transform=rainfall_transform,
            ) as dst:
                dst.write(resampled_lst[0], 1)
        
        print(f"Resampled LST saved to: {output_path}")

print("\nAll LST files have been resampled.")
# Out:
# Using reference rainfall file: /home/stormej/dev/varsha/data/reference_tif/refrence_tif.tif
# Reference rainfall data shape: (129, 135), CRS: EPSG:4326
#
# Processing: imd_25_delhi_2000-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2000-01.tif
#
# Processing: imd_25_delhi_2000-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2000-02.tif
#
# Processing: imd_25_delhi_2000-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2000-03.tif
#
# Processing: imd_25_delhi_2000-04.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2000-04.tif
#
# Processing: imd_25_delhi_2000-05.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2000-05.tif
#
# Processing: imd_25_delhi_2000-06.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2000-06.tif
#
# Processing: imd_25_delhi_2000-07.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2000-07.tif
#
# Processing: imd_25_delhi_2000-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2000-08.tif
#
# Processing: imd_25_delhi_2000-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2000-09.tif
#
# Processing: imd_25_delhi_2000-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2000-10.tif
#
# Processing: imd_25_delhi_2000-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2000-11.tif
#
# Processing: imd_25_delhi_2000-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2000-12.tif
#
# Processing: imd_25_delhi_2001-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2001-01.tif
#
# Processing: imd_25_delhi_2001-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2001-02.tif
#
# Processing: imd_25_delhi_2001-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2001-03.tif
#
# Processing: imd_25_delhi_2001-04.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2001-04.tif
#
# Processing: imd_25_delhi_2001-05.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2001-05.tif
#
# Processing: imd_25_delhi_2001-06.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2001-06.tif
#
# Processing: imd_25_delhi_2001-07.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2001-07.tif
#
# Processing: imd_25_delhi_2001-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2001-08.tif
#
# Processing: imd_25_delhi_2001-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2001-09.tif
#
# Processing: imd_25_delhi_2001-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2001-10.tif
#
# Processing: imd_25_delhi_2001-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2001-11.tif
#
# Processing: imd_25_delhi_2001-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2001-12.tif
#
# Processing: imd_25_delhi_2002-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2002-01.tif
#
# Processing: imd_25_delhi_2002-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2002-02.tif
#
# Processing: imd_25_delhi_2002-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2002-03.tif
#
# Processing: imd_25_delhi_2002-04.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2002-04.tif
#
# Processing: imd_25_delhi_2002-05.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2002-05.tif
#
# Processing: imd_25_delhi_2002-06.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2002-06.tif
#
# Processing: imd_25_delhi_2002-07.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2002-07.tif
#
# Processing: imd_25_delhi_2002-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2002-08.tif
#
# Processing: imd_25_delhi_2002-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2002-09.tif
#
# Processing: imd_25_delhi_2002-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2002-10.tif
#
# Processing: imd_25_delhi_2002-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2002-11.tif
#
# Processing: imd_25_delhi_2002-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2002-12.tif
#
# Processing: imd_25_delhi_2003-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2003-01.tif
#
# Processing: imd_25_delhi_2003-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2003-02.tif
#
# Processing: imd_25_delhi_2003-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2003-03.tif
#
# Processing: imd_25_delhi_2003-04.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2003-04.tif
#
# Processing: imd_25_delhi_2003-05.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2003-05.tif
#
# Processing: imd_25_delhi_2003-06.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2003-06.tif
#
# Processing: imd_25_delhi_2003-07.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2003-07.tif
#
# Processing: imd_25_delhi_2003-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2003-08.tif
#
# Processing: imd_25_delhi_2003-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2003-09.tif
#
# Processing: imd_25_delhi_2003-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2003-10.tif
#
# Processing: imd_25_delhi_2003-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2003-11.tif
#
# Processing: imd_25_delhi_2003-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2003-12.tif
#
# Processing: imd_25_delhi_2004-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2004-01.tif
#
# Processing: imd_25_delhi_2004-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2004-02.tif
#
# Processing: imd_25_delhi_2004-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2004-03.tif
#
# Processing: imd_25_delhi_2004-04.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2004-04.tif
#
# Processing: imd_25_delhi_2004-05.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2004-05.tif
#
# Processing: imd_25_delhi_2004-06.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2004-06.tif
#
# Processing: imd_25_delhi_2004-07.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2004-07.tif
#
# Processing: imd_25_delhi_2004-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2004-08.tif
#
# Processing: imd_25_delhi_2004-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2004-09.tif
#
# Processing: imd_25_delhi_2004-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2004-10.tif
#
# Processing: imd_25_delhi_2004-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2004-11.tif
#
# Processing: imd_25_delhi_2004-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2004-12.tif
#
# Processing: imd_25_delhi_2005-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2005-01.tif
#
# Processing: imd_25_delhi_2005-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2005-02.tif
#
# Processing: imd_25_delhi_2005-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2005-03.tif
#
# Processing: imd_25_delhi_2005-04.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2005-04.tif
#
# Processing: imd_25_delhi_2005-05.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2005-05.tif
#
# Processing: imd_25_delhi_2005-06.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2005-06.tif
#
# Processing: imd_25_delhi_2005-07.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2005-07.tif
#
# Processing: imd_25_delhi_2005-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2005-08.tif
#
# Processing: imd_25_delhi_2005-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2005-09.tif
#
# Processing: imd_25_delhi_2005-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2005-10.tif
#
# Processing: imd_25_delhi_2005-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2005-11.tif
#
# Processing: imd_25_delhi_2005-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2005-12.tif
#
# Processing: imd_25_delhi_2006-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2006-01.tif
#
# Processing: imd_25_delhi_2006-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2006-02.tif
#
# Processing: imd_25_delhi_2006-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2006-03.tif
#
# Processing: imd_25_delhi_2006-04.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2006-04.tif
#
# Processing: imd_25_delhi_2006-05.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2006-05.tif
#
# Processing: imd_25_delhi_2006-06.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2006-06.tif
#
# Processing: imd_25_delhi_2006-07.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2006-07.tif
#
# Processing: imd_25_delhi_2006-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2006-08.tif
#
# Processing: imd_25_delhi_2006-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2006-09.tif
#
# Processing: imd_25_delhi_2006-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2006-10.tif
#
# Processing: imd_25_delhi_2006-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2006-11.tif
#
# Processing: imd_25_delhi_2006-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2006-12.tif
#
# Processing: imd_25_delhi_2007-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2007-01.tif
#
# Processing: imd_25_delhi_2007-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2007-02.tif
#
# Processing: imd_25_delhi_2007-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2007-03.tif
#
# Processing: imd_25_delhi_2007-04.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2007-04.tif
#
# Processing: imd_25_delhi_2007-05.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2007-05.tif
#
# Processing: imd_25_delhi_2007-06.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2007-06.tif
#
# Processing: imd_25_delhi_2007-07.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2007-07.tif
#
# Processing: imd_25_delhi_2007-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2007-08.tif
#
# Processing: imd_25_delhi_2007-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2007-09.tif
#
# Processing: imd_25_delhi_2007-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2007-10.tif
#
# Processing: imd_25_delhi_2007-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2007-11.tif
#
# Processing: imd_25_delhi_2007-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2007-12.tif
#
# Processing: imd_25_delhi_2008-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2008-01.tif
#
# Processing: imd_25_delhi_2008-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2008-02.tif
#
# Processing: imd_25_delhi_2008-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2008-03.tif
#
# Processing: imd_25_delhi_2008-04.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2008-04.tif
#
# Processing: imd_25_delhi_2008-05.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2008-05.tif
#
# Processing: imd_25_delhi_2008-06.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2008-06.tif
#
# Processing: imd_25_delhi_2008-07.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2008-07.tif
#
# Processing: imd_25_delhi_2008-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2008-08.tif
#
# Processing: imd_25_delhi_2008-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2008-09.tif
#
# Processing: imd_25_delhi_2008-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2008-10.tif
#
# Processing: imd_25_delhi_2008-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2008-11.tif
#
# Processing: imd_25_delhi_2008-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2008-12.tif
#
# Processing: imd_25_delhi_2009-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2009-01.tif
#
# Processing: imd_25_delhi_2009-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2009-02.tif
#
# Processing: imd_25_delhi_2009-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2009-03.tif
#
# Processing: imd_25_delhi_2009-04.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2009-04.tif
#
# Processing: imd_25_delhi_2009-05.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2009-05.tif
#
# Processing: imd_25_delhi_2009-06.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2009-06.tif
#
# Processing: imd_25_delhi_2009-07.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2009-07.tif
#
# Processing: imd_25_delhi_2009-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2009-08.tif
#
# Processing: imd_25_delhi_2009-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2009-09.tif
#
# Processing: imd_25_delhi_2009-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2009-10.tif
#
# Processing: imd_25_delhi_2009-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2009-11.tif
#
# Processing: imd_25_delhi_2009-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2009-12.tif
#
# Processing: imd_25_delhi_2010-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2010-01.tif
#
# Processing: imd_25_delhi_2010-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2010-02.tif
#
# Processing: imd_25_delhi_2010-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2010-03.tif
#
# Processing: imd_25_delhi_2010-04.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2010-04.tif
#
# Processing: imd_25_delhi_2010-05.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2010-05.tif
#
# Processing: imd_25_delhi_2010-06.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2010-06.tif
#
# Processing: imd_25_delhi_2010-07.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2010-07.tif
#
# Processing: imd_25_delhi_2010-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2010-08.tif
#
# Processing: imd_25_delhi_2010-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2010-09.tif
#
# Processing: imd_25_delhi_2010-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2010-10.tif
#
# Processing: imd_25_delhi_2010-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2010-11.tif
#
# Processing: imd_25_delhi_2010-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2010-12.tif
#
# Processing: imd_25_delhi_2011-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2011-01.tif
#
# Processing: imd_25_delhi_2011-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2011-02.tif
#
# Processing: imd_25_delhi_2011-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2011-03.tif
#
# Processing: imd_25_delhi_2011-04.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2011-04.tif
#
# Processing: imd_25_delhi_2011-05.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2011-05.tif
#
# Processing: imd_25_delhi_2011-06.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2011-06.tif
#
# Processing: imd_25_delhi_2011-07.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2011-07.tif
#
# Processing: imd_25_delhi_2011-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2011-08.tif
#
# Processing: imd_25_delhi_2011-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2011-09.tif
#
# Processing: imd_25_delhi_2011-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2011-10.tif
#
# Processing: imd_25_delhi_2011-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2011-11.tif
#
# Processing: imd_25_delhi_2011-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2011-12.tif
#
# Processing: imd_25_delhi_2012-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2012-01.tif
#
# Processing: imd_25_delhi_2012-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2012-02.tif
#
# Processing: imd_25_delhi_2012-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2012-03.tif
#
# Processing: imd_25_delhi_2012-04.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2012-04.tif
#
# Processing: imd_25_delhi_2012-05.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2012-05.tif
#
# Processing: imd_25_delhi_2012-06.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2012-06.tif
#
# Processing: imd_25_delhi_2012-07.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2012-07.tif
#
# Processing: imd_25_delhi_2012-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2012-08.tif
#
# Processing: imd_25_delhi_2012-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2012-09.tif
#
# Processing: imd_25_delhi_2012-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2012-10.tif
#
# Processing: imd_25_delhi_2012-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2012-11.tif
#
# Processing: imd_25_delhi_2012-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2012-12.tif
#
# Processing: imd_25_delhi_2013-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2013-01.tif
#
# Processing: imd_25_delhi_2013-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2013-02.tif
#
# Processing: imd_25_delhi_2013-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2013-03.tif
#
# Processing: imd_25_delhi_2013-04.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2013-04.tif
#
# Processing: imd_25_delhi_2013-05.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2013-05.tif
#
# Processing: imd_25_delhi_2013-06.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2013-06.tif
#
# Processing: imd_25_delhi_2013-07.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2013-07.tif
#
# Processing: imd_25_delhi_2013-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2013-08.tif
#
# Processing: imd_25_delhi_2013-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2013-09.tif
#
# Processing: imd_25_delhi_2013-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2013-10.tif
#
# Processing: imd_25_delhi_2013-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2013-11.tif
#
# Processing: imd_25_delhi_2013-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2013-12.tif
#
# Processing: imd_25_delhi_2014-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2014-01.tif
#
# Processing: imd_25_delhi_2014-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2014-02.tif
#
# Processing: imd_25_delhi_2014-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2014-03.tif
#
# Processing: imd_25_delhi_2014-04.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2014-04.tif
#
# Processing: imd_25_delhi_2014-05.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2014-05.tif
#
# Processing: imd_25_delhi_2014-06.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2014-06.tif
#
# Processing: imd_25_delhi_2014-07.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2014-07.tif
#
# Processing: imd_25_delhi_2014-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2014-08.tif
#
# Processing: imd_25_delhi_2014-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2014-09.tif
#
# Processing: imd_25_delhi_2014-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2014-10.tif
#
# Processing: imd_25_delhi_2014-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2014-11.tif
#
# Processing: imd_25_delhi_2014-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2014-12.tif
#
# Processing: imd_25_delhi_2015-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2015-01.tif
#
# Processing: imd_25_delhi_2015-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2015-02.tif
#
# Processing: imd_25_delhi_2015-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2015-03.tif
#
# Processing: imd_25_delhi_2015-04.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2015-04.tif
#
# Processing: imd_25_delhi_2015-05.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2015-05.tif
#
# Processing: imd_25_delhi_2015-06.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2015-06.tif
#
# Processing: imd_25_delhi_2015-07.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2015-07.tif
#
# Processing: imd_25_delhi_2015-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2015-08.tif
#
# Processing: imd_25_delhi_2015-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2015-09.tif
#
# Processing: imd_25_delhi_2015-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2015-10.tif
#
# Processing: imd_25_delhi_2015-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2015-11.tif
#
# Processing: imd_25_delhi_2015-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2015-12.tif
#
# Processing: imd_25_delhi_2016-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2016-01.tif
#
# Processing: imd_25_delhi_2016-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2016-02.tif
#
# Processing: imd_25_delhi_2016-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2016-03.tif
#
# Processing: imd_25_delhi_2016-04.tif
# ...
#
# Processing: imd_25_delhi_2018-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2018-08.tif
#
# Processing: imd_25_delhi_2018-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2018-09.tif
#
# Processing: imd_25_delhi_2018-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2018-10.tif
#
# Processing: imd_25_delhi_2018-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2018-11.tif
#
# Processing: imd_25_delhi_2018-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2018-12.tif
#
# Processing: imd_25_delhi_2019-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2019-01.tif
#
# Processing: imd_25_delhi_2019-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2019-02.tif
#
# Processing: imd_25_delhi_2019-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2019-03.tif
#
# Processing: imd_25_delhi_2019-04.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2019-04.tif
#
# Processing: imd_25_delhi_2019-05.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2019-05.tif
#
# Processing: imd_25_delhi_2019-06.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2019-06.tif
#
# Processing: imd_25_delhi_2019-07.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2019-07.tif
#
# Processing: imd_25_delhi_2019-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2019-08.tif
#
# Processing: imd_25_delhi_2019-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2019-09.tif
#
# Processing: imd_25_delhi_2019-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2019-10.tif
#
# Processing: imd_25_delhi_2019-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2019-11.tif
#
# Processing: imd_25_delhi_2019-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2019-12.tif
#
# Processing: imd_25_delhi_2020-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2020-01.tif
#
# Processing: imd_25_delhi_2020-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2020-02.tif
#
# Processing: imd_25_delhi_2020-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2020-03.tif
#
# Processing: imd_25_delhi_2020-04.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2020-04.tif
#
# Processing: imd_25_delhi_2020-05.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2020-05.tif
#
# Processing: imd_25_delhi_2020-06.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2020-06.tif
#
# Processing: imd_25_delhi_2020-07.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2020-07.tif
#
# Processing: imd_25_delhi_2020-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2020-08.tif
#
# Processing: imd_25_delhi_2020-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2020-09.tif
#
# Processing: imd_25_delhi_2020-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2020-10.tif
#
# Processing: imd_25_delhi_2020-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2020-11.tif
#
# Processing: imd_25_delhi_2020-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2020-12.tif
#
# Processing: imd_25_delhi_2021-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2021-01.tif
#
# Processing: imd_25_delhi_2021-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2021-02.tif
#
# Processing: imd_25_delhi_2021-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2021-03.tif
#
# Processing: imd_25_delhi_2021-04.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2021-04.tif
#
# Processing: imd_25_delhi_2021-05.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2021-05.tif
#
# Processing: imd_25_delhi_2021-06.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2021-06.tif
#
# Processing: imd_25_delhi_2021-07.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2021-07.tif
#
# Processing: imd_25_delhi_2021-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2021-08.tif
#
# Processing: imd_25_delhi_2021-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2021-09.tif
#
# Processing: imd_25_delhi_2021-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2021-10.tif
#
# Processing: imd_25_delhi_2021-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2021-11.tif
#
# Processing: imd_25_delhi_2021-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2021-12.tif
#
# Processing: imd_25_delhi_2022-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2022-01.tif
#
# Processing: imd_25_delhi_2022-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2022-02.tif
#
# Processing: imd_25_delhi_2022-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2022-03.tif
#
# Processing: imd_25_delhi_2022-04.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2022-04.tif
#
# Processing: imd_25_delhi_2022-05.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2022-05.tif
#
# Processing: imd_25_delhi_2022-06.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2022-06.tif
#
# Processing: imd_25_delhi_2022-07.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2022-07.tif
#
# Processing: imd_25_delhi_2022-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2022-08.tif
#
# Processing: imd_25_delhi_2022-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2022-09.tif
#
# Processing: imd_25_delhi_2022-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2022-10.tif
#
# Processing: imd_25_delhi_2022-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2022-11.tif
#
# Processing: imd_25_delhi_2022-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2022-12.tif
#
# Processing: imd_25_delhi_2023-01.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2023-01.tif
#
# Processing: imd_25_delhi_2023-02.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2023-02.tif
#
# Processing: imd_25_delhi_2023-03.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2023-03.tif
#
# Processing: imd_25_delhi_2023-04.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2023-04.tif
#
# Processing: imd_25_delhi_2023-05.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2023-05.tif
#
# Processing: imd_25_delhi_2023-06.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2023-06.tif
#
# Processing: imd_25_delhi_2023-07.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2023-07.tif
#
# Processing: imd_25_delhi_2023-08.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2023-08.tif
#
# Processing: imd_25_delhi_2023-09.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2023-09.tif
#
# Processing: imd_25_delhi_2023-10.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2023-10.tif
#
# Processing: imd_25_delhi_2023-11.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2023-11.tif
#
# Processing: imd_25_delhi_2023-12.tif
# LST data shape: (3, 5), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/varsha/data/rain/rain_resampled_monthly/imd_rain_sum_resampled_2023-12.tif
#
# All LST files have been resampled.
