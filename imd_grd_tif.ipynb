# %%
pip install rioxarray

# %%
# !pip install numpy gdal==$(gdal-config --version)

# %%
# !pip install scipy

# %%
# !pip install matplotlib

# %%
# !pip install geopandas

# %%
from osgeo import gdal
import xarray as xr
import rioxarray as rxr
import os
from glob import glob
from datetime import datetime, timedelta
import numpy as np
import calendar
import numpy as n
import rasterio

# %%
import os
from datetime import datetime, timedelta
from glob import glob
import numpy as np
from osgeo import gdal, osr
import warnings
warnings.filterwarnings('ignore')

# Ensure all required packages are installed
# %pip install numpy gdal

def get_delhi_ncr_bounds():
    """Define the bounding box for Delhi NCR region"""
    return {
        'min_lon': 76.8,  # Western boundary (covers parts of Gurgaon)
        'max_lon': 77.6,  # Eastern boundary (covers parts of Ghaziabad/Noida)
        'min_lat': 28.4,  # Southern boundary 
        'max_lat': 28.9   # Northern boundary
    }

def convert_grd_to_clipped_tif(grd_file, output_dir):
    """Convert GRD file to daily GeoTIFF files clipped to Delhi NCR region"""
    try:
        # Extract year from filename (assuming format YYYY.grd)
        year = os.path.basename(grd_file).split('.')[0]
        print(f"Processing year: {year}")
        
        # Open the .grd file and read its content
        with open(grd_file, 'rb') as f:
            data = f.read()
        print(f"Read {len(data)} bytes from {grd_file}")
        
        # Determine the number of days in the year
        is_leap_year = (int(year) % 4 == 0 and int(year) % 100 != 0) or (int(year) % 400 == 0)
        days_in_year = 366 if is_leap_year else 365
        print(f"Year {year} has {days_in_year} days")
        
        # Convert binary data to numpy array
        all_data = np.frombuffer(data, dtype=np.float32)
        
        # For 0.25° x 0.25° grid covering India
        grid_size = 129 * 135  # Total number of grid cells
        
        # Get Delhi NCR bounds
        bounds = get_delhi_ncr_bounds()
        
        # Calculate array indices for clipping
        min_x = int((bounds['min_lon'] - 65.0) / 0.25)
        max_x = int((bounds['max_lon'] - 65.0) / 0.25)
        min_y = int((40.0 - bounds['max_lat']) / 0.25)  # Flip Y coordinates
        max_y = int((40.0 - bounds['min_lat']) / 0.25)
        
        # Calculate new dimensions
        new_width = max_x - min_x + 1
        new_height = max_y - min_y + 1
        
        for day in range(days_in_year):
            date = datetime(int(year), 1, 1) + timedelta(days=day)
            output_filename = f"imd_25_delhi_{date.strftime('%Y-%m-%d')}.tif"
            output_file = os.path.join(output_dir, output_filename)
            
            # Extract data for the current day
            day_data = all_data[day * grid_size : (day + 1) * grid_size].reshape(129, 135)
            
            # Flip the data vertically
            day_data = np.flipud(day_data)
            
            # Clip the data to Southern India region
            clipped_data = day_data[min_y:max_y+1, min_x:max_x+1]
            
            # Create a new GeoTIFF file
            driver = gdal.GetDriverByName('GTiff')
            dataset = driver.Create(output_file, new_width, new_height, 1, gdal.GDT_Float32)
            
            # Set geotransform for the clipped region
            geotransform = (
                bounds['min_lon'],  # Left edge
                0.25,               # Pixel width
                0,                  # Rotation (0 if image is "north up")
                bounds['max_lat'],  # Top edge
                0,                  # Rotation (0 if image is "north up")
                -0.25               # Pixel height (negative as it goes from top to bottom)
            )
            dataset.SetGeoTransform(geotransform)
            
            # Set projection (WGS84)
            srs = osr.SpatialReference()
            srs.ImportFromEPSG(4326)
            dataset.SetProjection(srs.ExportToWkt())
            
            # Write the clipped data
            dataset.GetRasterBand(1).WriteArray(clipped_data)
            
            # Set NoData value
            dataset.GetRasterBand(1).SetNoDataValue(-999)
            
            # Close the dataset
            dataset = None
            
            if os.path.exists(output_file):
                print(f"Successfully saved {output_file} (size: {os.path.getsize(output_file)} bytes)")
            else:
                print(f"Failed to create {output_file}")
            
    except Exception as e:
        print(f"Failed to process {grd_file}: {str(e)}")
        raise

def main():
    # Define the directory containing the rainfall .grd files
    rainfall_dir = r'/home/stormej/dev/btech-project/data/rain_grd'
    
    # Define the output directory for the clipped .tif files
    output_dir = r'/home/stormej/dev/btech-project/data/rain_tif'
    os.makedirs(output_dir, exist_ok=True)
    
    # List all .grd files in the rainfall directory
    grd_files = glob(os.path.join(rainfall_dir, '*.grd'))
    
    if not grd_files:
        print(f"No .grd files found in {rainfall_dir}")
    else:
        for grd_file in grd_files:
            print(f"Processing {grd_file}...")
            convert_grd_to_clipped_tif(grd_file, output_dir)
    
    print("Script execution completed.")

if __name__ == "__main__":
    main()

# %%
import rasterio
from rasterio.merge import merge
from rasterio.plot import show
import numpy as np
import os
from glob import glob
from datetime import datetime

def aggregate_daily_to_monthly(input_dir, output_dir):
    """Aggregate daily GeoTIFF files to monthly GeoTIFF files"""
    os.makedirs(output_dir, exist_ok=True)
    
    # List all daily .tif files in the input directory
    daily_files = glob(os.path.join(input_dir, 'imd_25_delhi_*.tif'))
    
    if not daily_files:
        print(f"No daily .tif files found in {input_dir}")
        return
    
    # Dictionary to hold monthly data
    monthly_data = {}
    
    for daily_file in daily_files:
        # Extract date from filename
        date_str = os.path.basename(daily_file).split('_')[-1].split('.')[0]
        date = datetime.strptime(date_str, '%Y-%m-%d')
        month_str = date.strftime('%Y-%m')
        
        # Read the daily data
        with rasterio.open(daily_file) as src:
            daily_data = src.read(1)
            profile = src.profile
        
        # Initialize monthly data if not already done
        if month_str not in monthly_data:
            monthly_data[month_str] = []
        
        # Append daily data to the corresponding month
        monthly_data[month_str].append(daily_data)
    
    # Aggregate daily data to monthly data
    for month_str, daily_data_list in monthly_data.items():
        # Stack daily data and calculate the sum
        stacked_data = np.stack(daily_data_list, axis=0)
        monthly_sum_data = np.sum(stacked_data, axis=0)
        
        # Create output filename
        output_filename = f"imd_25_delhi_{month_str}.tif"
        output_file = os.path.join(output_dir, output_filename)
        
        # Write the monthly data to a new GeoTIFF file
        with rasterio.open(output_file, 'w', **profile) as dst:
            dst.write(monthly_sum_data, 1)
        
        print(f"Successfully saved {output_file}")

# Define the input directory containing the daily .tif files
input_dir = r'/home/stormej/dev/btech-project/data/rain_tif'

# Define the output directory for the monthly .tif files
output_dir = r'/home/stormej/dev/btech-project/data/rain_monthly_tif'

# Aggregate daily data to monthly data
aggregate_daily_to_monthly(input_dir, output_dir)
# Out:
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2000-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2000-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2000-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2000-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2000-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2000-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2000-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2000-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2000-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2000-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2000-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2000-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2001-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2001-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2001-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2001-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2001-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2001-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2001-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2001-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2001-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2001-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2001-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2001-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2002-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2002-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2002-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2002-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2002-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2002-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2002-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2002-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2002-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2002-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2002-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2002-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2003-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2003-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2003-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2003-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2003-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2003-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2003-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2003-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2003-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2003-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2003-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2003-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2004-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2004-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2004-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2004-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2004-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2004-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2004-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2004-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2004-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2004-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2004-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2004-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2005-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2005-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2005-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2005-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2005-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2005-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2005-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2005-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2005-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2005-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2005-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2005-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2006-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2006-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2006-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2006-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2006-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2006-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2006-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2006-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2006-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2006-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2006-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2006-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2007-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2007-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2007-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2007-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2007-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2007-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2007-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2007-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2007-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2007-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2007-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2007-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2008-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2008-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2008-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2008-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2008-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2008-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2008-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2008-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2008-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2008-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2008-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2008-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2009-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2009-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2009-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2009-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2009-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2009-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2009-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2009-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2009-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2009-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2009-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2009-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2010-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2010-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2010-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2010-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2010-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2010-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2010-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2010-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2010-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2010-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2010-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2010-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2011-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2011-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2011-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2011-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2011-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2011-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2011-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2011-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2011-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2011-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2011-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2011-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2012-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2012-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2012-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2012-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2012-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2012-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2012-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2012-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2012-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2012-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2012-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2012-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2013-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2013-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2013-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2013-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2013-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2013-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2013-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2013-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2013-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2013-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2013-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2013-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2014-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2014-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2014-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2014-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2014-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2014-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2014-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2014-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2014-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2014-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2014-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2014-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2015-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2015-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2015-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2015-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2015-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2015-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2015-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2015-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2015-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2015-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2015-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2015-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2016-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2016-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2016-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2016-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2016-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2016-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2016-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2016-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2016-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2016-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2016-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2016-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2017-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2017-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2017-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2017-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2017-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2017-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2017-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2017-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2017-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2017-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2017-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2017-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2018-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2018-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2018-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2018-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2018-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2018-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2018-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2018-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2018-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2018-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2018-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2018-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2019-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2019-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2019-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2019-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2019-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2019-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2019-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2019-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2019-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2019-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2019-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2019-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2020-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2020-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2020-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2020-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2020-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2020-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2020-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2020-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2020-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2020-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2020-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2020-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2021-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2021-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2021-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2021-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2021-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2021-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2021-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2021-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2021-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2021-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2021-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2021-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2022-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2022-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2022-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2022-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2022-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2022-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2022-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2022-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2022-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2022-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2022-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2022-12.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2023-01.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2023-02.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2023-03.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2023-04.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2023-05.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2023-06.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2023-07.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2023-08.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2023-09.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2023-10.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2023-11.tif
# Successfully saved /home/stormej/dev/btech-project/data/rain_monthly_tif/imd_25_delhi_2023-12.tif

# %%
#Resampling rainfall monthly data to imd data i.e 0.25 degree

import os
import rasterio
from rasterio.enums import Resampling
# # Paths
# rainfall_folder = r'/home/stormej/dev/btech-project/data/rain_tif'  # Folder containing all rainfall files
rainfall_folder = r'/home/stormej/dev/btech-project/data/reference_tif'  # Folder containing reference files
input_folder = r'/home/stormej/dev/btech-project/data/rain_monthly_tif'  # Folder containing all LST files
output_folder = r'/home/stormej/dev/btech-project/data/rain_resampled_monthly'  # Folder to save resampled files

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)


# Find a reference rainfall file
reference_rainfall_path = None
for filename in os.listdir(rainfall_folder):
    if filename.endswith('.tif'):
        reference_rainfall_path = os.path.join(rainfall_folder, filename)
        break

if reference_rainfall_path is None:
    raise FileNotFoundError("No TIF file found in the rainfall folder")

print(f"Using reference rainfall file: {reference_rainfall_path}")

# Open the reference rainfall file to get its properties
with rasterio.open(reference_rainfall_path) as rainfall_src:
    rainfall_shape = (rainfall_src.height, rainfall_src.width)
    rainfall_crs = rainfall_src.crs
    rainfall_transform = rainfall_src.transform

print(f"Reference rainfall data shape: {rainfall_shape}, CRS: {rainfall_crs}")

# Process all LST files in the folder
for filename in os.listdir(input_folder):
    if filename.endswith('.tif'):
        lst_path = os.path.join(input_folder, filename)
        print(f"\nProcessing: {filename}")
        
        with rasterio.open(lst_path) as lst_src:
            lst_data = lst_src.read(1)
            print(f"LST data shape: {lst_data.shape}, dtype: {lst_data.dtype}")
            
            # Resample LST data using average method
            resampled_lst = lst_src.read(
                out_shape=(1, rainfall_shape[0], rainfall_shape[1]),
                resampling=Resampling.average
            )
            print(f"Resampled LST shape: {resampled_lst.shape}, dtype: {resampled_lst.dtype}")
            
            # Extract date from LST filename (handling format: lst_south_2010-01-01.tif)
            # Split by underscore and get the last part before .tif
            date_part = filename.split('_')[-1].split('.')[0]
            
            # Create output filename
            output_filename = f'imd_rain_sum_resampled_{date_part}.tif'
            output_path = os.path.join(output_folder, output_filename)
            
            # Save the resampled LST
            with rasterio.open(
                output_path,
                'w',
                driver='GTiff',
                height=resampled_lst.shape[1],
                width=resampled_lst.shape[2],
                count=1,
                dtype=resampled_lst.dtype,
                crs=rainfall_crs,
                transform=rainfall_transform,
            ) as dst:
                dst.write(resampled_lst[0], 1)
        
        print(f"Resampled LST saved to: {output_path}")

print("\nAll LST files have been resampled.")
# Out:
# Using reference rainfall file: /home/stormej/dev/btech-project/data/reference_tif/refrence_tif.tif
# Reference rainfall data shape: (129, 135), CRS: EPSG:4326
#
# Processing: imd_25_delhi_2000-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2000-01.tif
#
# Processing: imd_25_delhi_2000-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2000-02.tif
#
# Processing: imd_25_delhi_2000-03.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2000-03.tif
#
# Processing: imd_25_delhi_2000-04.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2000-04.tif
#
# Processing: imd_25_delhi_2000-05.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2000-05.tif
#
# Processing: imd_25_delhi_2000-06.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2000-06.tif
#
# Processing: imd_25_delhi_2000-07.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2000-07.tif
#
# Processing: imd_25_delhi_2000-08.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2000-08.tif
#
# Processing: imd_25_delhi_2000-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2000-09.tif
#
# Processing: imd_25_delhi_2000-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2000-10.tif
#
# Processing: imd_25_delhi_2000-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2000-11.tif
#
# Processing: imd_25_delhi_2000-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2000-12.tif
#
# Processing: imd_25_delhi_2001-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2001-01.tif
#
# Processing: imd_25_delhi_2001-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2001-02.tif
#
# Processing: imd_25_delhi_2001-03.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2001-03.tif
#
# Processing: imd_25_delhi_2001-04.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2001-04.tif
#
# Processing: imd_25_delhi_2001-05.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2001-05.tif
#
# Processing: imd_25_delhi_2001-06.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2001-06.tif
#
# Processing: imd_25_delhi_2001-07.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2001-07.tif
#
# Processing: imd_25_delhi_2001-08.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2001-08.tif
#
# Processing: imd_25_delhi_2001-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2001-09.tif
#
# Processing: imd_25_delhi_2001-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2001-10.tif
#
# Processing: imd_25_delhi_2001-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2001-11.tif
#
# Processing: imd_25_delhi_2001-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2001-12.tif
#
# Processing: imd_25_delhi_2002-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2002-01.tif
#
# Processing: imd_25_delhi_2002-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2002-02.tif
#
# Processing: imd_25_delhi_2002-03.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2002-03.tif
#
# Processing: imd_25_delhi_2002-04.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2002-04.tif
#
# Processing: imd_25_delhi_2002-05.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2002-05.tif
#
# Processing: imd_25_delhi_2002-06.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2002-06.tif
#
# Processing: imd_25_delhi_2002-07.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2002-07.tif
#
# Processing: imd_25_delhi_2002-08.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2002-08.tif
#
# Processing: imd_25_delhi_2002-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2002-09.tif
#
# Processing: imd_25_delhi_2002-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2002-10.tif
#
# Processing: imd_25_delhi_2002-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2002-11.tif
#
# Processing: imd_25_delhi_2002-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2002-12.tif
#
# Processing: imd_25_delhi_2003-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2003-01.tif
#
# Processing: imd_25_delhi_2003-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2003-02.tif
#
# Processing: imd_25_delhi_2003-03.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2003-03.tif
#
# Processing: imd_25_delhi_2003-04.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2003-04.tif
#
# Processing: imd_25_delhi_2003-05.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2003-05.tif
#
# Processing: imd_25_delhi_2003-06.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2003-06.tif
#
# Processing: imd_25_delhi_2003-07.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2003-07.tif
#
# Processing: imd_25_delhi_2003-08.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2003-08.tif
#
# Processing: imd_25_delhi_2003-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2003-09.tif
#
# Processing: imd_25_delhi_2003-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2003-10.tif
#
# Processing: imd_25_delhi_2003-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2003-11.tif
#
# Processing: imd_25_delhi_2003-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2003-12.tif
#
# Processing: imd_25_delhi_2004-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2004-01.tif
#
# Processing: imd_25_delhi_2004-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2004-02.tif
#
# Processing: imd_25_delhi_2004-03.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2004-03.tif
#
# Processing: imd_25_delhi_2004-04.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2004-04.tif
#
# Processing: imd_25_delhi_2004-05.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2004-05.tif
#
# Processing: imd_25_delhi_2004-06.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2004-06.tif
#
# Processing: imd_25_delhi_2004-07.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2004-07.tif
#
# Processing: imd_25_delhi_2004-08.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2004-08.tif
#
# Processing: imd_25_delhi_2004-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2004-09.tif
#
# Processing: imd_25_delhi_2004-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2004-10.tif
#
# Processing: imd_25_delhi_2004-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2004-11.tif
#
# Processing: imd_25_delhi_2004-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2004-12.tif
#
# Processing: imd_25_delhi_2005-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2005-01.tif
#
# Processing: imd_25_delhi_2005-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2005-02.tif
#
# Processing: imd_25_delhi_2005-03.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2005-03.tif
#
# Processing: imd_25_delhi_2005-04.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2005-04.tif
#
# Processing: imd_25_delhi_2005-05.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2005-05.tif
#
# Processing: imd_25_delhi_2005-06.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2005-06.tif
#
# Processing: imd_25_delhi_2005-07.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2005-07.tif
#
# Processing: imd_25_delhi_2005-08.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2005-08.tif
#
# Processing: imd_25_delhi_2005-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2005-09.tif
#
# Processing: imd_25_delhi_2005-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2005-10.tif
#
# Processing: imd_25_delhi_2005-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2005-11.tif
#
# Processing: imd_25_delhi_2005-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2005-12.tif
#
# Processing: imd_25_delhi_2006-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2006-01.tif
#
# Processing: imd_25_delhi_2006-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2006-02.tif
#
# Processing: imd_25_delhi_2006-03.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2006-03.tif
#
# Processing: imd_25_delhi_2006-04.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2006-04.tif
#
# Processing: imd_25_delhi_2006-05.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2006-05.tif
#
# Processing: imd_25_delhi_2006-06.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2006-06.tif
#
# Processing: imd_25_delhi_2006-07.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2006-07.tif
#
# Processing: imd_25_delhi_2006-08.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2006-08.tif
#
# Processing: imd_25_delhi_2006-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2006-09.tif
#
# Processing: imd_25_delhi_2006-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2006-10.tif
#
# Processing: imd_25_delhi_2006-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2006-11.tif
#
# Processing: imd_25_delhi_2006-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2006-12.tif
#
# Processing: imd_25_delhi_2007-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2007-01.tif
#
# Processing: imd_25_delhi_2007-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2007-02.tif
#
# Processing: imd_25_delhi_2007-03.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2007-03.tif
#
# Processing: imd_25_delhi_2007-04.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2007-04.tif
#
# Processing: imd_25_delhi_2007-05.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2007-05.tif
#
# Processing: imd_25_delhi_2007-06.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2007-06.tif
#
# Processing: imd_25_delhi_2007-07.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2007-07.tif
#
# Processing: imd_25_delhi_2007-08.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2007-08.tif
#
# Processing: imd_25_delhi_2007-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2007-09.tif
#
# Processing: imd_25_delhi_2007-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2007-10.tif
#
# Processing: imd_25_delhi_2007-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2007-11.tif
#
# Processing: imd_25_delhi_2007-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2007-12.tif
#
# Processing: imd_25_delhi_2008-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2008-01.tif
#
# Processing: imd_25_delhi_2008-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2008-02.tif
#
# Processing: imd_25_delhi_2008-03.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2008-03.tif
#
# Processing: imd_25_delhi_2008-04.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2008-04.tif
#
# Processing: imd_25_delhi_2008-05.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2008-05.tif
#
# Processing: imd_25_delhi_2008-06.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2008-06.tif
#
# Processing: imd_25_delhi_2008-07.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2008-07.tif
#
# Processing: imd_25_delhi_2008-08.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2008-08.tif
#
# Processing: imd_25_delhi_2008-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2008-09.tif
#
# Processing: imd_25_delhi_2008-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2008-10.tif
#
# Processing: imd_25_delhi_2008-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2008-11.tif
#
# Processing: imd_25_delhi_2008-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2008-12.tif
#
# Processing: imd_25_delhi_2009-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2009-01.tif
#
# Processing: imd_25_delhi_2009-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2009-02.tif
#
# Processing: imd_25_delhi_2009-03.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2009-03.tif
#
# Processing: imd_25_delhi_2009-04.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2009-04.tif
#
# Processing: imd_25_delhi_2009-05.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2009-05.tif
#
# Processing: imd_25_delhi_2009-06.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2009-06.tif
#
# Processing: imd_25_delhi_2009-07.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2009-07.tif
#
# Processing: imd_25_delhi_2009-08.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2009-08.tif
#
# Processing: imd_25_delhi_2009-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2009-09.tif
#
# Processing: imd_25_delhi_2009-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2009-10.tif
#
# Processing: imd_25_delhi_2009-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2009-11.tif
#
# Processing: imd_25_delhi_2009-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2009-12.tif
#
# Processing: imd_25_delhi_2010-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2010-01.tif
#
# Processing: imd_25_delhi_2010-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2010-02.tif
#
# Processing: imd_25_delhi_2010-03.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2010-03.tif
#
# Processing: imd_25_delhi_2010-04.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2010-04.tif
#
# Processing: imd_25_delhi_2010-05.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2010-05.tif
#
# Processing: imd_25_delhi_2010-06.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2010-06.tif
#
# Processing: imd_25_delhi_2010-07.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2010-07.tif
#
# Processing: imd_25_delhi_2010-08.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2010-08.tif
#
# Processing: imd_25_delhi_2010-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2010-09.tif
#
# Processing: imd_25_delhi_2010-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2010-10.tif
#
# Processing: imd_25_delhi_2010-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2010-11.tif
#
# Processing: imd_25_delhi_2010-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2010-12.tif
#
# Processing: imd_25_delhi_2011-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2011-01.tif
#
# Processing: imd_25_delhi_2011-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2011-02.tif
#
# Processing: imd_25_delhi_2011-03.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2011-03.tif
#
# Processing: imd_25_delhi_2011-04.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2011-04.tif
#
# Processing: imd_25_delhi_2011-05.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2011-05.tif
#
# Processing: imd_25_delhi_2011-06.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2011-06.tif
#
# Processing: imd_25_delhi_2011-07.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2011-07.tif
#
# Processing: imd_25_delhi_2011-08.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2011-08.tif
#
# Processing: imd_25_delhi_2011-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2011-09.tif
#
# Processing: imd_25_delhi_2011-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2011-10.tif
#
# Processing: imd_25_delhi_2011-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2011-11.tif
#
# Processing: imd_25_delhi_2011-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2011-12.tif
#
# Processing: imd_25_delhi_2012-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2012-01.tif
#
# Processing: imd_25_delhi_2012-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2012-02.tif
#
# Processing: imd_25_delhi_2012-03.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2012-03.tif
#
# Processing: imd_25_delhi_2012-04.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2012-04.tif
#
# Processing: imd_25_delhi_2012-05.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2012-05.tif
#
# Processing: imd_25_delhi_2012-06.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2012-06.tif
#
# Processing: imd_25_delhi_2012-07.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2012-07.tif
#
# Processing: imd_25_delhi_2012-08.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2012-08.tif
#
# Processing: imd_25_delhi_2012-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2012-09.tif
#
# Processing: imd_25_delhi_2012-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2012-10.tif
#
# Processing: imd_25_delhi_2012-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2012-11.tif
#
# Processing: imd_25_delhi_2012-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2012-12.tif
#
# Processing: imd_25_delhi_2013-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2013-01.tif
#
# Processing: imd_25_delhi_2013-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2013-02.tif
#
# Processing: imd_25_delhi_2013-03.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2013-03.tif
#
# Processing: imd_25_delhi_2013-04.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2013-04.tif
#
# Processing: imd_25_delhi_2013-05.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2013-05.tif
#
# Processing: imd_25_delhi_2013-06.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2013-06.tif
#
# Processing: imd_25_delhi_2013-07.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2013-07.tif
#
# Processing: imd_25_delhi_2013-08.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2013-08.tif
#
# Processing: imd_25_delhi_2013-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2013-09.tif
#
# Processing: imd_25_delhi_2013-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2013-10.tif
#
# Processing: imd_25_delhi_2013-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2013-11.tif
#
# Processing: imd_25_delhi_2013-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2013-12.tif
#
# Processing: imd_25_delhi_2014-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2014-01.tif
#
# Processing: imd_25_delhi_2014-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2014-02.tif
#
# Processing: imd_25_delhi_2014-03.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2014-03.tif
#
# Processing: imd_25_delhi_2014-04.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2014-04.tif
#
# Processing: imd_25_delhi_2014-05.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2014-05.tif
#
# Processing: imd_25_delhi_2014-06.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2014-06.tif
#
# Processing: imd_25_delhi_2014-07.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2014-07.tif
#
# Processing: imd_25_delhi_2014-08.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2014-08.tif
#
# Processing: imd_25_delhi_2014-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2014-09.tif
#
# Processing: imd_25_delhi_2014-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2014-10.tif
#
# Processing: imd_25_delhi_2014-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2014-11.tif
#
# Processing: imd_25_delhi_2014-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2014-12.tif
#
# Processing: imd_25_delhi_2015-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2015-01.tif
#
# Processing: imd_25_delhi_2015-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2015-02.tif
#
# Processing: imd_25_delhi_2015-03.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2015-03.tif
#
# Processing: imd_25_delhi_2015-04.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2015-04.tif
#
# Processing: imd_25_delhi_2015-05.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2015-05.tif
#
# Processing: imd_25_delhi_2015-06.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2015-06.tif
#
# Processing: imd_25_delhi_2015-07.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2015-07.tif
#
# Processing: imd_25_delhi_2015-08.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2015-08.tif
#
# Processing: imd_25_delhi_2015-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2015-09.tif
#
# Processing: imd_25_delhi_2015-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2015-10.tif
#
# Processing: imd_25_delhi_2015-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2015-11.tif
#
# Processing: imd_25_delhi_2015-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2015-12.tif
#
# Processing: imd_25_delhi_2016-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2016-01.tif
#
# Processing: imd_25_delhi_2016-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# ...
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2018-08.tif
#
# Processing: imd_25_delhi_2018-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2018-09.tif
#
# Processing: imd_25_delhi_2018-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2018-10.tif
#
# Processing: imd_25_delhi_2018-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2018-11.tif
#
# Processing: imd_25_delhi_2018-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2018-12.tif
#
# Processing: imd_25_delhi_2019-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2019-01.tif
#
# Processing: imd_25_delhi_2019-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2019-02.tif
#
# Processing: imd_25_delhi_2019-03.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2019-03.tif
#
# Processing: imd_25_delhi_2019-04.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2019-04.tif
#
# Processing: imd_25_delhi_2019-05.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2019-05.tif
#
# Processing: imd_25_delhi_2019-06.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2019-06.tif
#
# Processing: imd_25_delhi_2019-07.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2019-07.tif
#
# Processing: imd_25_delhi_2019-08.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2019-08.tif
#
# Processing: imd_25_delhi_2019-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2019-09.tif
#
# Processing: imd_25_delhi_2019-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2019-10.tif
#
# Processing: imd_25_delhi_2019-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2019-11.tif
#
# Processing: imd_25_delhi_2019-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2019-12.tif
#
# Processing: imd_25_delhi_2020-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2020-01.tif
#
# Processing: imd_25_delhi_2020-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2020-02.tif
#
# Processing: imd_25_delhi_2020-03.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2020-03.tif
#
# Processing: imd_25_delhi_2020-04.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2020-04.tif
#
# Processing: imd_25_delhi_2020-05.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2020-05.tif
#
# Processing: imd_25_delhi_2020-06.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2020-06.tif
#
# Processing: imd_25_delhi_2020-07.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2020-07.tif
#
# Processing: imd_25_delhi_2020-08.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2020-08.tif
#
# Processing: imd_25_delhi_2020-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2020-09.tif
#
# Processing: imd_25_delhi_2020-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2020-10.tif
#
# Processing: imd_25_delhi_2020-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2020-11.tif
#
# Processing: imd_25_delhi_2020-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2020-12.tif
#
# Processing: imd_25_delhi_2021-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2021-01.tif
#
# Processing: imd_25_delhi_2021-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2021-02.tif
#
# Processing: imd_25_delhi_2021-03.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2021-03.tif
#
# Processing: imd_25_delhi_2021-04.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2021-04.tif
#
# Processing: imd_25_delhi_2021-05.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2021-05.tif
#
# Processing: imd_25_delhi_2021-06.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2021-06.tif
#
# Processing: imd_25_delhi_2021-07.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2021-07.tif
#
# Processing: imd_25_delhi_2021-08.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2021-08.tif
#
# Processing: imd_25_delhi_2021-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2021-09.tif
#
# Processing: imd_25_delhi_2021-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2021-10.tif
#
# Processing: imd_25_delhi_2021-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2021-11.tif
#
# Processing: imd_25_delhi_2021-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2021-12.tif
#
# Processing: imd_25_delhi_2022-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2022-01.tif
#
# Processing: imd_25_delhi_2022-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2022-02.tif
#
# Processing: imd_25_delhi_2022-03.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2022-03.tif
#
# Processing: imd_25_delhi_2022-04.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2022-04.tif
#
# Processing: imd_25_delhi_2022-05.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2022-05.tif
#
# Processing: imd_25_delhi_2022-06.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2022-06.tif
#
# Processing: imd_25_delhi_2022-07.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2022-07.tif
#
# Processing: imd_25_delhi_2022-08.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2022-08.tif
#
# Processing: imd_25_delhi_2022-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2022-09.tif
#
# Processing: imd_25_delhi_2022-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2022-10.tif
#
# Processing: imd_25_delhi_2022-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2022-11.tif
#
# Processing: imd_25_delhi_2022-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2022-12.tif
#
# Processing: imd_25_delhi_2023-01.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2023-01.tif
#
# Processing: imd_25_delhi_2023-02.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2023-02.tif
#
# Processing: imd_25_delhi_2023-03.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2023-03.tif
#
# Processing: imd_25_delhi_2023-04.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2023-04.tif
#
# Processing: imd_25_delhi_2023-05.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2023-05.tif
#
# Processing: imd_25_delhi_2023-06.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2023-06.tif
#
# Processing: imd_25_delhi_2023-07.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2023-07.tif
#
# Processing: imd_25_delhi_2023-08.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2023-08.tif
#
# Processing: imd_25_delhi_2023-09.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2023-09.tif
#
# Processing: imd_25_delhi_2023-10.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2023-10.tif
#
# Processing: imd_25_delhi_2023-11.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2023-11.tif
#
# Processing: imd_25_delhi_2023-12.tif
# LST data shape: (3, 4), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/rain_resampled_monthly/imd_rain_sum_resampled_2023-12.tif
#
# All LST files have been resampled.
