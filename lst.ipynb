# %%
import ee
import geemap
import geopandas as gpd
import os
from datetime import datetime, timedelta
import xarray as xr
import rioxarray
import rasterio
from rasterio.enums import Resampling
import numpy as np
from collections import defaultdict

# %%
import ee

# Trigger the authentication flow.
ee.Authenticate()

# Initialize the library.
ee.Initialize(project='btech-project-443813') # Make sure this project ID is correct

# %%
import ee
import geemap
import os
from datetime import datetime, timedelta

def initialize_ee():
    """Initialize Earth Engine"""
    try:
        ee.Initialize()
        print("Earth Engine initialized successfully")
    except Exception as e:
        print(f"Error initializing Earth Engine: {str(e)}")
        raise

def create_new_delhi_rectangle():
    """Create Earth Engine rectangle geometry for New Delhi region"""
    return ee.Geometry.Rectangle([
        76.8,  # min_lon (Western boundary)
        28.4,  # min_lat (Southern boundary)
        77.6,  # max_lon (Eastern boundary)
        28.9   # max_lat (Northern boundary)
    ])

def kelvin_to_celsius(image):
    """Convert LST from Kelvin to Celsius"""
    lst_band = image.select('LST_Day_1km').multiply(0.02)  # Scale factor applied
    lst_celsius = lst_band.subtract(273.15)  # Convert K to °C
    return image.addBands(lst_celsius.rename('LST_Celsius'))

def get_composite_lst(start_date, roi):
    """Get 8-day composite LST"""
    try:
        # Convert datetime to ee.Date
        ee_start_date = ee.Date(start_date.strftime('%Y-%m-%d'))
        ee_end_date = ee_start_date.advance(8, 'day')
        
        # Get MODIS LST 8-day composite data (MOD11A2.061 product)
        dataset = ee.ImageCollection('MODIS/061/MOD11A2') \
            .filterDate(ee_start_date, ee_end_date) \
            .filterBounds(roi)
        
        # Get LST image and apply quality filter
        lst_image = dataset.mean()  # Use mean to get composite
        
        # Check if we have data
        if dataset.size().getInfo() == 0:
            raise Exception("No LST data available for this period")
        
        # Get quality control band and cast to unsigned integer
        qc = lst_image.select('QC_Day').toUint8()
        
        # Create quality mask (bits 1-0 = 00, meaning good quality)
        # MODIS QC bits: 00=good quality, 01=other quality, 10=invalid, 11=cloud
        good_quality = qc.bitwiseAnd(ee.Number(3)).eq(0)
        
        # Apply quality mask and convert to Celsius
        lst_processed = kelvin_to_celsius(lst_image) \
            .updateMask(good_quality) \
            .select('LST_Celsius') \
            .clip(roi)
        
        return lst_processed
    
    except Exception as e:
        print(f"Error processing LST composite for {start_date.strftime('%Y-%m-%d')}: {str(e)}")
        raise

def download_composite_lst(start_date, roi, output_directory):
    """Download 8-day composite LST"""
    try:
        date_str = start_date.strftime('%Y-%m-%d')
        lst = get_composite_lst(start_date, roi)
        filename = os.path.join(output_directory, f'lst_delhi_composite_{date_str}.tif')
        
        # Get the region coordinates for geemap
        region = roi.getInfo()['coordinates'][0]
        
        # Use geemap to download and convert to GeoTIFF
        geemap.ee_export_image(
            lst,
            filename=filename,
            scale=1000,  # 1km resolution
            region=region,
            crs='EPSG:4326',
            file_per_band=False
        )
        
        if os.path.exists(filename):
            file_size = os.path.getsize(filename)
            print(f"Successfully downloaded LST composite for {date_str} (Size: {file_size/1024:.1f} KB)")
            return True
        else:
            print(f"Failed to download LST composite for {date_str}")
            return False
            
    except Exception as e:
        print(f"Error downloading LST composite for {date_str}: {str(e)}")
        return False

def main():
    # Initialize Earth Engine
    initialize_ee()
    
    # Define the region of interest for Southern India
    roi = create_new_delhi_rectangle()
    
    # Define the date range
    start_date = datetime(2000, 1, 1)
    end_date = datetime(2023, 3, 31)
    
    # Create output directory
    output_directory = r"/home/stormej/dev/btech-project/data/lst_tif"
    os.makedirs(output_directory, exist_ok=True)
    
    # Download 8-day composite LST data for each period in the date range
    current_date = start_date
    successful_downloads = 0
    failed_downloads = 0
    
    print(f"\nStarting download of 8-day composite LST data from {start_date.strftime('%Y-%m-%d')} to {end_date.strftime('%Y-%m-%d')}...")
    
    while current_date <= end_date:
        try:
            print(f"\nProcessing {current_date.strftime('%Y-%m-%d')} to {(current_date + timedelta(days=7)).strftime('%Y-%m-%d')}")
            
            if download_composite_lst(current_date, roi, output_directory):
                successful_downloads += 1
            else:
                failed_downloads += 1
                
        except Exception as e:
            print(f"Error processing {current_date.strftime('%Y-%m-%d')}: {str(e)}")
            failed_downloads += 1
            
        # Move to the next 8-day period
        current_date += timedelta(days=8)
    
    print("\nDownload Summary:")
    print(f"Successfully downloaded: {successful_downloads} periods")
    print(f"Failed downloads: {failed_downloads} periods")
    print("Process completed.")

if __name__ == "__main__":
    main()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Earth Engine initialized successfully
#
# Starting download of 8-day composite LST data from 2000-01-01 to 2023-03-31...
#
# Processing 2000-01-01 to 2000-01-08
# Error processing LST composite for 2000-01-01: No LST data available for this period
# Error downloading LST composite for 2000-01-01: No LST data available for this period
#
# Processing 2000-01-09 to 2000-01-16
# Error processing LST composite for 2000-01-09: No LST data available for this period
# Error downloading LST composite for 2000-01-09: No LST data available for this period
#
# Processing 2000-01-17 to 2000-01-24
# Error processing LST composite for 2000-01-17: No LST data available for this period
# Error downloading LST composite for 2000-01-17: No LST data available for this period
#
# Processing 2000-01-25 to 2000-02-01
# Error processing LST composite for 2000-01-25: No LST data available for this period
# Error downloading LST composite for 2000-01-25: No LST data available for this period
#
# Processing 2000-02-02 to 2000-02-09
# Error processing LST composite for 2000-02-02: No LST data available for this period
# Error downloading LST composite for 2000-02-02: No LST data available for this period
#
# Processing 2000-02-10 to 2000-02-17
# Error processing LST composite for 2000-02-10: No LST data available for this period
# Error downloading LST composite for 2000-02-10: No LST data available for this period
#
# Processing 2000-02-18 to 2000-02-25
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/20fa016fc9f541856d63a8cea2ba7011-ec9278d68db6980c3cbf75e84be2ac30:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/lst_tif/lst_delhi_composite_2000-02-18.tif
# Successfully downloaded LST composite for 2000-02-18 (Size: 0.9 KB)
#
# Processing 2000-02-26 to 2000-03-04
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/4d97e30c0a6da93afb5fd0e38ee13830-4ae98c6d34b0105627c5ae3543c6cb6d:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/lst_tif/lst_delhi_composite_2000-02-26.tif
# Successfully downloaded LST composite for 2000-02-26 (Size: 9.3 KB)
#
# Processing 2000-03-05 to 2000-03-12
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/2115e15cf72c446e1d46350125f9a250-174ca71fddb3e73e68313b10b4e70078:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/lst_tif/lst_delhi_composite_2000-03-05.tif
# Successfully downloaded LST composite for 2000-03-05 (Size: 9.5 KB)
#
# Processing 2000-03-13 to 2000-03-20
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/4d50ad19a7461157fc068a99e7894714-f368efda559c333068f8d14b74166954:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/lst_tif/lst_delhi_composite_2000-03-13.tif
# Successfully downloaded LST composite for 2000-03-13 (Size: 10.0 KB)
#
# Processing 2000-03-21 to 2000-03-28
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/933db0d46fdfd67505ab61a5cf8c2842-86d2e4c0539d9aa6f64119b179a31af1:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/lst_tif/lst_delhi_composite_2022-12-31.tif
# Successfully downloaded LST composite for 2022-12-31 (Size: 4.5 KB)
#
# Processing 2023-01-08 to 2023-01-15
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/8d6935d7d35ca32bf8e071d57fb4c7c2-150881f1e622c85b093860c65948acdf:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/lst_tif/lst_delhi_composite_2023-01-08.tif
# Successfully downloaded LST composite for 2023-01-08 (Size: 7.8 KB)
#
# Processing 2023-01-16 to 2023-01-23
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/62df3f2e0e4d99db63702f1763f45571-03e1301c07f2e1a767b76f6eda5c311c:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/lst_tif/lst_delhi_composite_2023-01-16.tif
# Successfully downloaded LST composite for 2023-01-16 (Size: 6.5 KB)
#
# Processing 2023-01-24 to 2023-01-31
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/ade41c8f0b799f6990c406ac1be399a2-25d3106780b1873df2fe6b4c269d557c:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/lst_tif/lst_delhi_composite_2023-01-24.tif
# Successfully downloaded LST composite for 2023-01-24 (Size: 8.7 KB)
#
# Processing 2023-02-01 to 2023-02-08
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/43107b4967c42c43710eee4e37ac9f25-c4ffd6e901dd34b9cc5365ece5187043:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/lst_tif/lst_delhi_composite_2023-02-01.tif
# Successfully downloaded LST composite for 2023-02-01 (Size: 6.9 KB)
#
# Processing 2023-02-09 to 2023-02-16
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/2c178a8631bc1bc94c8671da52aa88c5-f895a1b531374a13aa6dad650dad1a94:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/lst_tif/lst_delhi_composite_2023-02-09.tif
# Successfully downloaded LST composite for 2023-02-09 (Size: 5.3 KB)
#
# Processing 2023-02-17 to 2023-02-24
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/bbcaaf0d58dbad1af86a1648ad6ff97f-ecdca23d475827bcbe2a232b77b8418d:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/lst_tif/lst_delhi_composite_2023-02-17.tif
# Successfully downloaded LST composite for 2023-02-17 (Size: 8.5 KB)
#
# Processing 2023-02-25 to 2023-03-04
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/a148dc2bcec551193333f8ffa5811242-47e701c035d93ec3b83b2ba504ddda9e:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/lst_tif/lst_delhi_composite_2023-02-25.tif
# Successfully downloaded LST composite for 2023-02-25 (Size: 8.6 KB)
#
# Processing 2023-03-05 to 2023-03-12
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/407823d67401b7ce75ecaef39f5f2a12-66954d9d75cc11d1a2c7f3379e29c506:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/lst_tif/lst_delhi_composite_2023-03-05.tif
# Successfully downloaded LST composite for 2023-03-05 (Size: 9.6 KB)
#
# Processing 2023-03-13 to 2023-03-20
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/4ab0abafa7ce89864723516aed7f1aad-81680585f498ec2e3d91017adf6a45f4:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/lst_tif/lst_delhi_composite_2023-03-13.tif
# Successfully downloaded LST composite for 2023-03-13 (Size: 9.7 KB)
#
# Processing 2023-03-21 to 2023-03-28
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/949ea358236d1a1d1fd4d064870ab4dc-44d5b0702f1c8bd9d97acecad03f7452:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/lst_tif/lst_delhi_composite_2023-03-21.tif
# Successfully downloaded LST composite for 2023-03-21 (Size: 8.6 KB)
#
# Processing 2023-03-29 to 2023-04-05
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/243489042939/thumbnails/eee14f780c422bee3f231150c12a70e0-795e214ab3e398cbe3b8a32f89dde677:getPixels
# Please wait ...
# Data downloaded to /home/stormej/dev/btech-project/data/lst_tif/lst_delhi_composite_2023-03-29.tif
# Successfully downloaded LST composite for 2023-03-29 (Size: 9.1 KB)
#
# Download Summary:
# Successfully downloaded: 1055 periods
# Failed downloads: 7 periods
# Process completed.

# %%
#Resampling lst monthly data to imd data i.e 0.25 degree

import os
import rasterio
from rasterio.enums import Resampling
# # Paths
# rainfall_folder = r'/home/stormej/dev/btech-project/data/rain_tif'  # Folder containing all rainfall files
rainfall_folder = r'/home/stormej/dev/btech-project/data/reference_tif'  # Folder containing reference files
lst_folder = r'/home/stormej/dev/btech-project/data/lst_tif_monthly'  # Folder containing all LST files
output_folder = r'/home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled'  # Folder to save resampled files

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)


# Find a reference rainfall file
reference_rainfall_path = None
for filename in os.listdir(rainfall_folder):
    if filename.endswith('.tif'):
        reference_rainfall_path = os.path.join(rainfall_folder, filename)
        break

if reference_rainfall_path is None:
    raise FileNotFoundError("No TIF file found in the rainfall folder")

print(f"Using reference rainfall file: {reference_rainfall_path}")

# Open the reference rainfall file to get its properties
with rasterio.open(reference_rainfall_path) as rainfall_src:
    rainfall_shape = (rainfall_src.height, rainfall_src.width)
    rainfall_crs = rainfall_src.crs
    rainfall_transform = rainfall_src.transform

print(f"Reference rainfall data shape: {rainfall_shape}, CRS: {rainfall_crs}")

# Process all LST files in the folder
for filename in os.listdir(lst_folder):
    if filename.endswith('.tif'):
        lst_path = os.path.join(lst_folder, filename)
        print(f"\nProcessing: {filename}")
        
        with rasterio.open(lst_path) as lst_src:
            lst_data = lst_src.read(1)
            print(f"LST data shape: {lst_data.shape}, dtype: {lst_data.dtype}")
            
            # Resample LST data using average method
            resampled_lst = lst_src.read(
                out_shape=(1, rainfall_shape[0], rainfall_shape[1]),
                resampling=Resampling.average
            )
            print(f"Resampled LST shape: {resampled_lst.shape}, dtype: {resampled_lst.dtype}")
            
            # Extract date from LST filename (handling format: lst_south_2010-01-01.tif)
            # Split by underscore and get the last part before .tif
            date_part = filename.split('_')[-1].split('.')[0]
            
            # Create output filename
            output_filename = f'modis_lst_avg_resampled_{date_part}.tif'
            output_path = os.path.join(output_folder, output_filename)
            
            # Save the resampled LST
            with rasterio.open(
                output_path,
                'w',
                driver='GTiff',
                height=resampled_lst.shape[1],
                width=resampled_lst.shape[2],
                count=1,
                dtype=resampled_lst.dtype,
                crs=rainfall_crs,
                transform=rainfall_transform,
            ) as dst:
                dst.write(resampled_lst[0], 1)
        
        print(f"Resampled LST saved to: {output_path}")

print("\nAll LST files have been resampled.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Using reference rainfall file: /home/stormej/dev/btech-project/data/reference_tif/refrence_tif.tif
# Reference rainfall data shape: (129, 135), CRS: EPSG:4326
#
# Processing: lst_monthly_mean_2000-02.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2000-02.tif
#
# Processing: lst_monthly_mean_2000-03.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2000-03.tif
#
# Processing: lst_monthly_mean_2000-04.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2000-04.tif
#
# Processing: lst_monthly_mean_2000-05.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2000-05.tif
#
# Processing: lst_monthly_mean_2000-06.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2000-06.tif
#
# Processing: lst_monthly_mean_2000-07.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2000-07.tif
#
# Processing: lst_monthly_mean_2000-08.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2000-08.tif
#
# Processing: lst_monthly_mean_2000-09.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2000-09.tif
#
# Processing: lst_monthly_mean_2000-10.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2000-10.tif
#
# Processing: lst_monthly_mean_2000-11.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2000-11.tif
#
# Processing: lst_monthly_mean_2000-12.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2000-12.tif
#
# Processing: lst_monthly_mean_2001-01.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2001-01.tif
#
# Processing: lst_monthly_mean_2001-02.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2001-02.tif
#
# Processing: lst_monthly_mean_2001-03.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2001-03.tif
#
# Processing: lst_monthly_mean_2001-04.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2001-04.tif
#
# Processing: lst_monthly_mean_2001-05.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2001-05.tif
#
# Processing: lst_monthly_mean_2001-06.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2001-06.tif
#
# Processing: lst_monthly_mean_2001-07.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2001-07.tif
#
# Processing: lst_monthly_mean_2001-08.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2001-08.tif
#
# Processing: lst_monthly_mean_2001-09.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2001-09.tif
#
# Processing: lst_monthly_mean_2001-10.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2001-10.tif
#
# Processing: lst_monthly_mean_2001-11.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2001-11.tif
#
# Processing: lst_monthly_mean_2001-12.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2001-12.tif
#
# Processing: lst_monthly_mean_2002-01.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2002-01.tif
#
# Processing: lst_monthly_mean_2002-02.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2002-02.tif
#
# Processing: lst_monthly_mean_2002-03.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2002-03.tif
#
# Processing: lst_monthly_mean_2002-04.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2002-04.tif
#
# Processing: lst_monthly_mean_2002-05.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2002-05.tif
#
# Processing: lst_monthly_mean_2002-06.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2002-06.tif
#
# Processing: lst_monthly_mean_2002-07.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2002-07.tif
#
# Processing: lst_monthly_mean_2002-08.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2002-08.tif
#
# Processing: lst_monthly_mean_2002-09.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2002-09.tif
#
# Processing: lst_monthly_mean_2002-10.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2002-10.tif
#
# Processing: lst_monthly_mean_2002-11.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2002-11.tif
#
# Processing: lst_monthly_mean_2002-12.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2002-12.tif
#
# Processing: lst_monthly_mean_2003-01.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2003-01.tif
#
# Processing: lst_monthly_mean_2003-02.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2003-02.tif
#
# Processing: lst_monthly_mean_2003-03.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2003-03.tif
#
# Processing: lst_monthly_mean_2003-04.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2003-04.tif
#
# Processing: lst_monthly_mean_2003-05.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2003-05.tif
#
# Processing: lst_monthly_mean_2003-06.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2003-06.tif
#
# Processing: lst_monthly_mean_2003-07.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2003-07.tif
#
# Processing: lst_monthly_mean_2003-08.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2003-08.tif
#
# Processing: lst_monthly_mean_2003-09.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2003-09.tif
#
# Processing: lst_monthly_mean_2003-10.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2003-10.tif
#
# Processing: lst_monthly_mean_2003-11.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2003-11.tif
#
# Processing: lst_monthly_mean_2003-12.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2003-12.tif
#
# Processing: lst_monthly_mean_2004-01.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2004-01.tif
#
# Processing: lst_monthly_mean_2004-02.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2004-02.tif
#
# Processing: lst_monthly_mean_2004-03.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2004-03.tif
#
# Processing: lst_monthly_mean_2004-04.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2004-04.tif
#
# Processing: lst_monthly_mean_2004-05.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2004-05.tif
#
# Processing: lst_monthly_mean_2004-06.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2004-06.tif
#
# Processing: lst_monthly_mean_2004-07.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2004-07.tif
#
# Processing: lst_monthly_mean_2004-08.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2004-08.tif
#
# Processing: lst_monthly_mean_2004-09.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2004-09.tif
#
# Processing: lst_monthly_mean_2004-10.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2004-10.tif
#
# Processing: lst_monthly_mean_2004-11.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2004-11.tif
#
# Processing: lst_monthly_mean_2004-12.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2004-12.tif
#
# Processing: lst_monthly_mean_2005-01.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2005-01.tif
#
# Processing: lst_monthly_mean_2005-02.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2005-02.tif
#
# Processing: lst_monthly_mean_2005-03.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2005-03.tif
#
# Processing: lst_monthly_mean_2005-04.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2005-04.tif
#
# Processing: lst_monthly_mean_2005-05.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2005-05.tif
#
# Processing: lst_monthly_mean_2005-06.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2005-06.tif
#
# Processing: lst_monthly_mean_2005-07.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2005-07.tif
#
# Processing: lst_monthly_mean_2005-08.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2005-08.tif
#
# Processing: lst_monthly_mean_2005-09.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2005-09.tif
#
# Processing: lst_monthly_mean_2005-10.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2005-10.tif
#
# Processing: lst_monthly_mean_2005-11.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2005-11.tif
#
# Processing: lst_monthly_mean_2005-12.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2005-12.tif
#
# Processing: lst_monthly_mean_2006-01.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2006-01.tif
#
# Processing: lst_monthly_mean_2006-02.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2006-02.tif
#
# Processing: lst_monthly_mean_2006-03.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2006-03.tif
#
# Processing: lst_monthly_mean_2006-04.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2006-04.tif
#
# Processing: lst_monthly_mean_2006-05.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2006-05.tif
#
# Processing: lst_monthly_mean_2006-06.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2006-06.tif
#
# Processing: lst_monthly_mean_2006-07.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2006-07.tif
#
# Processing: lst_monthly_mean_2006-08.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2006-08.tif
#
# Processing: lst_monthly_mean_2006-09.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2006-09.tif
#
# Processing: lst_monthly_mean_2006-10.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2006-10.tif
#
# Processing: lst_monthly_mean_2006-11.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2006-11.tif
#
# Processing: lst_monthly_mean_2006-12.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2006-12.tif
#
# Processing: lst_monthly_mean_2007-01.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2007-01.tif
#
# Processing: lst_monthly_mean_2007-02.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2007-02.tif
#
# Processing: lst_monthly_mean_2007-03.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2007-03.tif
#
# Processing: lst_monthly_mean_2007-04.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2007-04.tif
#
# Processing: lst_monthly_mean_2007-05.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2007-05.tif
#
# Processing: lst_monthly_mean_2007-06.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2007-06.tif
#
# Processing: lst_monthly_mean_2007-07.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2007-07.tif
#
# Processing: lst_monthly_mean_2007-08.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2007-08.tif
#
# Processing: lst_monthly_mean_2007-09.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2007-09.tif
#
# Processing: lst_monthly_mean_2007-10.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2007-10.tif
#
# Processing: lst_monthly_mean_2007-11.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2007-11.tif
#
# Processing: lst_monthly_mean_2007-12.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2007-12.tif
#
# Processing: lst_monthly_mean_2008-01.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2008-01.tif
#
# Processing: lst_monthly_mean_2008-02.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2008-02.tif
#
# Processing: lst_monthly_mean_2008-03.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2008-03.tif
#
# Processing: lst_monthly_mean_2008-04.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2008-04.tif
#
# Processing: lst_monthly_mean_2008-05.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2008-05.tif
#
# Processing: lst_monthly_mean_2008-06.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2008-06.tif
#
# Processing: lst_monthly_mean_2008-07.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2008-07.tif
#
# Processing: lst_monthly_mean_2008-08.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2008-08.tif
#
# Processing: lst_monthly_mean_2008-09.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2008-09.tif
#
# Processing: lst_monthly_mean_2008-10.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2008-10.tif
#
# Processing: lst_monthly_mean_2008-11.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2008-11.tif
#
# Processing: lst_monthly_mean_2008-12.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2008-12.tif
#
# Processing: lst_monthly_mean_2009-01.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2009-01.tif
#
# Processing: lst_monthly_mean_2009-02.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2009-02.tif
#
# Processing: lst_monthly_mean_2009-03.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2009-03.tif
#
# Processing: lst_monthly_mean_2009-04.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2009-04.tif
#
# Processing: lst_monthly_mean_2009-05.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2009-05.tif
#
# Processing: lst_monthly_mean_2009-06.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2009-06.tif
#
# Processing: lst_monthly_mean_2009-07.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2009-07.tif
#
# Processing: lst_monthly_mean_2009-08.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2009-08.tif
#
# Processing: lst_monthly_mean_2009-09.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2009-09.tif
#
# Processing: lst_monthly_mean_2009-10.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2009-10.tif
#
# Processing: lst_monthly_mean_2009-11.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2009-11.tif
#
# Processing: lst_monthly_mean_2009-12.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2009-12.tif
#
# Processing: lst_monthly_mean_2010-01.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2010-01.tif
#
# Processing: lst_monthly_mean_2010-02.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2010-02.tif
#
# Processing: lst_monthly_mean_2010-03.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2010-03.tif
#
# Processing: lst_monthly_mean_2010-04.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2010-04.tif
#
# Processing: lst_monthly_mean_2010-05.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2010-05.tif
#
# Processing: lst_monthly_mean_2010-06.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2010-06.tif
#
# Processing: lst_monthly_mean_2010-07.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2010-07.tif
#
# Processing: lst_monthly_mean_2010-08.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2010-08.tif
#
# Processing: lst_monthly_mean_2010-09.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2010-09.tif
#
# Processing: lst_monthly_mean_2010-10.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2010-10.tif
#
# Processing: lst_monthly_mean_2010-11.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2010-11.tif
#
# Processing: lst_monthly_mean_2010-12.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2010-12.tif
#
# Processing: lst_monthly_mean_2011-01.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2011-01.tif
#
# Processing: lst_monthly_mean_2011-02.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2011-02.tif
#
# Processing: lst_monthly_mean_2011-03.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2011-03.tif
#
# Processing: lst_monthly_mean_2011-04.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2011-04.tif
#
# Processing: lst_monthly_mean_2011-05.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2011-05.tif
#
# Processing: lst_monthly_mean_2011-06.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2011-06.tif
#
# Processing: lst_monthly_mean_2011-07.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2011-07.tif
#
# Processing: lst_monthly_mean_2011-08.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2011-08.tif
#
# Processing: lst_monthly_mean_2011-09.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2011-09.tif
#
# Processing: lst_monthly_mean_2011-10.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2011-10.tif
#
# Processing: lst_monthly_mean_2011-11.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2011-11.tif
#
# Processing: lst_monthly_mean_2011-12.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2011-12.tif
#
# Processing: lst_monthly_mean_2012-01.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2012-01.tif
#
# Processing: lst_monthly_mean_2012-02.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2012-02.tif
#
# Processing: lst_monthly_mean_2012-03.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2012-03.tif
#
# Processing: lst_monthly_mean_2012-04.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2012-04.tif
#
# Processing: lst_monthly_mean_2012-05.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2012-05.tif
#
# Processing: lst_monthly_mean_2012-06.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2012-06.tif
#
# Processing: lst_monthly_mean_2012-07.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2012-07.tif
#
# Processing: lst_monthly_mean_2012-08.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2012-08.tif
#
# Processing: lst_monthly_mean_2012-09.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2012-09.tif
#
# Processing: lst_monthly_mean_2012-10.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2012-10.tif
#
# Processing: lst_monthly_mean_2012-11.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2012-11.tif
#
# Processing: lst_monthly_mean_2012-12.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2012-12.tif
#
# Processing: lst_monthly_mean_2013-01.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2013-01.tif
#
# Processing: lst_monthly_mean_2013-02.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2013-02.tif
#
# Processing: lst_monthly_mean_2013-03.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2013-03.tif
#
# Processing: lst_monthly_mean_2013-04.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2013-04.tif
#
# Processing: lst_monthly_mean_2013-05.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2013-05.tif
#
# Processing: lst_monthly_mean_2013-06.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2013-06.tif
#
# Processing: lst_monthly_mean_2013-07.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2013-07.tif
#
# Processing: lst_monthly_mean_2013-08.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2013-08.tif
#
# Processing: lst_monthly_mean_2013-09.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2013-09.tif
#
# Processing: lst_monthly_mean_2013-10.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2013-10.tif
#
# Processing: lst_monthly_mean_2013-11.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2013-11.tif
#
# Processing: lst_monthly_mean_2013-12.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2013-12.tif
#
# Processing: lst_monthly_mean_2014-01.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2014-01.tif
#
# Processing: lst_monthly_mean_2014-02.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2014-02.tif
#
# Processing: lst_monthly_mean_2014-03.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2014-03.tif
#
# Processing: lst_monthly_mean_2014-04.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2014-04.tif
#
# Processing: lst_monthly_mean_2014-05.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2014-05.tif
#
# Processing: lst_monthly_mean_2014-06.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2014-06.tif
#
# Processing: lst_monthly_mean_2014-07.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2014-07.tif
#
# Processing: lst_monthly_mean_2014-08.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2014-08.tif
#
# ...
#
# Processing: lst_monthly_mean_2018-05.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2018-05.tif
#
# Processing: lst_monthly_mean_2018-06.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2018-06.tif
#
# Processing: lst_monthly_mean_2018-07.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2018-07.tif
#
# Processing: lst_monthly_mean_2018-08.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2018-08.tif
#
# Processing: lst_monthly_mean_2018-09.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2018-09.tif
#
# Processing: lst_monthly_mean_2018-10.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2018-10.tif
#
# Processing: lst_monthly_mean_2018-11.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2018-11.tif
#
# Processing: lst_monthly_mean_2018-12.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2018-12.tif
#
# Processing: lst_monthly_mean_2019-01.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2019-01.tif
#
# Processing: lst_monthly_mean_2019-02.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2019-02.tif
#
# Processing: lst_monthly_mean_2019-03.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2019-03.tif
#
# Processing: lst_monthly_mean_2019-04.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2019-04.tif
#
# Processing: lst_monthly_mean_2019-05.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2019-05.tif
#
# Processing: lst_monthly_mean_2019-06.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2019-06.tif
#
# Processing: lst_monthly_mean_2019-07.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2019-07.tif
#
# Processing: lst_monthly_mean_2019-08.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2019-08.tif
#
# Processing: lst_monthly_mean_2019-09.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2019-09.tif
#
# Processing: lst_monthly_mean_2019-10.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2019-10.tif
#
# Processing: lst_monthly_mean_2019-11.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2019-11.tif
#
# Processing: lst_monthly_mean_2019-12.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2019-12.tif
#
# Processing: lst_monthly_mean_2020-01.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2020-01.tif
#
# Processing: lst_monthly_mean_2020-02.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2020-02.tif
#
# Processing: lst_monthly_mean_2020-03.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2020-03.tif
#
# Processing: lst_monthly_mean_2020-04.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2020-04.tif
#
# Processing: lst_monthly_mean_2020-05.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2020-05.tif
#
# Processing: lst_monthly_mean_2020-06.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2020-06.tif
#
# Processing: lst_monthly_mean_2020-07.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2020-07.tif
#
# Processing: lst_monthly_mean_2020-08.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2020-08.tif
#
# Processing: lst_monthly_mean_2020-09.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2020-09.tif
#
# Processing: lst_monthly_mean_2020-10.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2020-10.tif
#
# Processing: lst_monthly_mean_2020-11.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2020-11.tif
#
# Processing: lst_monthly_mean_2020-12.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2020-12.tif
#
# Processing: lst_monthly_mean_2021-01.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2021-01.tif
#
# Processing: lst_monthly_mean_2021-02.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2021-02.tif
#
# Processing: lst_monthly_mean_2021-03.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2021-03.tif
#
# Processing: lst_monthly_mean_2021-04.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2021-04.tif
#
# Processing: lst_monthly_mean_2021-05.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2021-05.tif
#
# Processing: lst_monthly_mean_2021-06.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2021-06.tif
#
# Processing: lst_monthly_mean_2021-07.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2021-07.tif
#
# Processing: lst_monthly_mean_2021-08.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2021-08.tif
#
# Processing: lst_monthly_mean_2021-09.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2021-09.tif
#
# Processing: lst_monthly_mean_2021-10.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2021-10.tif
#
# Processing: lst_monthly_mean_2021-11.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2021-11.tif
#
# Processing: lst_monthly_mean_2021-12.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2021-12.tif
#
# Processing: lst_monthly_mean_2022-01.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2022-01.tif
#
# Processing: lst_monthly_mean_2022-02.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2022-02.tif
#
# Processing: lst_monthly_mean_2022-03.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2022-03.tif
#
# Processing: lst_monthly_mean_2022-04.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2022-04.tif
#
# Processing: lst_monthly_mean_2022-05.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2022-05.tif
#
# Processing: lst_monthly_mean_2022-06.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2022-06.tif
#
# Processing: lst_monthly_mean_2022-07.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2022-07.tif
#
# Processing: lst_monthly_mean_2022-08.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2022-08.tif
#
# Processing: lst_monthly_mean_2022-09.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2022-09.tif
#
# Processing: lst_monthly_mean_2022-10.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2022-10.tif
#
# Processing: lst_monthly_mean_2022-11.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2022-11.tif
#
# Processing: lst_monthly_mean_2022-12.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2022-12.tif
#
# Processing: lst_monthly_mean_2023-01.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2023-01.tif
#
# Processing: lst_monthly_mean_2023-02.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2023-02.tif
#
# Processing: lst_monthly_mean_2023-03.tif
# LST data shape: (57, 90), dtype: float32
# Resampled LST shape: (1, 129, 135), dtype: float32
# Resampled LST saved to: /home/stormej/dev/btech-project/data/lst_composite_delhi_monthly_resampled/modis_lst_avg_resampled_2023-03.tif
#
# All LST files have been resampled.
